# %% [markdown]
# # １导入必要的库

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import lightgbm as lgb
import pandas as pd
import numpy as np
import gc
from tqdm import tqdm_notebook as tqdm
import copy

# %% [markdown]
# # 2 载入必要的文件

# %%
train=pd.read_csv('../data/meinian_round1_train_20180408.csv',sep=',',encoding='gbk')
test=pd.read_csv('../data/meinian_round1_test_b_20180505.csv',sep=',',encoding='gbk')
data_part1=pd.read_csv('../data/meinian_round1_data_part1_20180408.zip',sep='$',encoding='utf-8')
data_part2=pd.read_csv('../data/meinian_round1_data_part2_20180408.zip',sep='$',encoding='utf-8')
physical_data = data_part1.append(data_part2)

# %% [markdown]
# # 3 基本数据处理

# %%
physical_data['field_results'] = physical_data['field_results'].astype('str')
physical_data = pd.pivot_table(physical_data,index='vid',columns='table_id',values='field_results',aggfunc=lambda x: '_'.join(x))
physical_data.to_pickle('../data/physical_data.pkl')
index = np.save('../data/index.npy',physical_data.index)

# %% [markdown]
# # 4 EDA,及一些对数据的人为分析，后续看不懂的地方都在这一步完成．

# %% [markdown]
# # 5 数据清洗及特征提取

# %%
# 增加项目数作为特征
physical_data.reset_index(drop=True,inplace=True)
physical_data['subject_num'] = 2795-physical_data.isnull().sum(axis=1)
column_name = physical_data.columns
drop_column = []
valid_column = []
valid_df = pd.DataFrame()
for f in range(len(column_name)):
    if physical_data.iloc[:,f].isnull().sum()>55000:
        drop_column.append(f)
    else:
        valid_column.append(f)
print('%d 列缺失值超过阈值'%len(drop_column))
new_df = pd.DataFrame()
for i in valid_column:
    new_df[column_name[i]] = physical_data.iloc[:,i]
print(new_df.shape)

# 统计特征类型数目
physical_data = new_df
column_name = list(physical_data.columns.values)
numerical_feature = []
for item in tqdm(column_name):
    try:
        physical_data[item] = physical_data[item].astype('float16')
        numerical_feature.append(item)
    except:
        continue
str_feature = []
for item in column_name:
    if item not in numerical_feature:
        str_feature.append(item)
print('数值特征数目%d'% (len(numerical_feature)))
print('字符特征数目%d'%(len(str_feature)))

# clean the data
#数据预处理之删除所有空格，替换ＩI,替换'阴性'为'-',
#[用'_'分割一模一样则合并,有nan则删除，有数字和其他则保留数字，都是数字取平均值,doushi]，从<0.6提取关键信息
str_feature = physical_data.columns
for j in tqdm(str_feature):
    row = []
    for i in range(len(physical_data)):
        value = physical_data.loc[i,j]
        value = str(value).strip()
        if value in ['nan','None']:
            row.append(np.NaN)
        else:
            try:
                row.append(float(value))
            except:
                if '_' in value:
                    value_list = []
                    for sub_value in value.split('_'):
                        # 去空格
                        sub_value = str(sub_value).strip()
                        # 去空值
                        if sub_value in ['nan','None']:
                            continue
                        else:
                            try:
                                value_list.append(float(value))
                            except:
                                if '未检' in sub_value or '弃查' in sub_value or '未查' in sub_value or '未检查'in sub_value:
                                    continue
                                else:
                                    sub_value = sub_value.replace('阴性','-')
                                    sub_value = sub_value.replace('阳性','+')
                                    sub_value = sub_value.replace('偏阳','+-')
                                    sub_value = sub_value.replace('P','+')
                                    sub_value = sub_value.replace('p','+')
                                    sub_value = sub_value.replace('N','-')
                                    sub_value = sub_value.replace('IV','4')
                                    sub_value = sub_value.replace('V','5')
                                    sub_value = sub_value.replace('III','3')
                                    sub_value = sub_value.replace('II','2')
                                    sub_value = sub_value.replace('I','1')
                                    sub_value = sub_value.replace('。','.')
                                    sub_value = sub_value.strip('.')
                                    sub_value = sub_value.strip('°')
                                    sub_value = sub_value.strip('%')
                                    sub_value = sub_value.strip('度')
                                    sub_value = sub_value.strip('mmol/L')
                                    sub_value = sub_value.strip('自述不查')
                                    sub_value = sub_value.strip('详见报告单')
                                    sub_value = sub_value.strip('/')
                                    sub_value = sub_value.strip('标本已退检')
                                    sub_value = sub_value.strip()
                                    sub_value = sub_value.replace('..','.')
                                    sub_value = sub_value.replace('＜','<')
                                    sub_value = sub_value.replace('＞','>')
                                    sub_value = sub_value.replace('>','')
                                    sub_value = sub_value.replace('<','')
                                    sub_value = sub_value.replace('＋','+')
                                    sub_value = sub_value.replace('－','-')
                                    sub_value = sub_value.replace('iv','４')
                                    sub_value = sub_value.replace('iii','3')
                                    sub_value = sub_value.replace('ii','2')
                                    sub_value = sub_value.replace('i','1')
                                    sub_value = sub_value.replace('Ⅲ','3')
                                    sub_value = sub_value.replace('Ⅱ','2')
                                    sub_value = sub_value.replace('Ⅰ','1')
                                    sub_value = sub_value.replace('Ⅳ','4')
                                    sub_value = sub_value.replace('中度','2')
                                value_list.append(sub_value)
                    if value_list == []:
                        row.append(np.NaN)
                    else:
                        # 去重
                        value_list = list(set(value_list))
                        # 都是数字，取平均值
                        try:
                            row.append(np.mean([float(x) for x in value_list]))
                        except:
                            flag = False
                            for sth in value_list:
                                try:
                                    float(sth)
                                    row.append(sth)
                                    flag = True
                                    break
                                except:
                                    continue
                            
                            if flag:
                                pass
                            else:
                                value_list = '_'.join(value_list)
                                row.append(value_list)
                else:
                    sub_value = value
                    if '未检' in sub_value or '弃查' in sub_value or '未查' in sub_value or '未检查'in sub_value:
                        row.append(np.NaN)
                    else:
                        sub_value = sub_value.replace('阴性','-')
                        sub_value = sub_value.replace('阳性','+')
                        sub_value = sub_value.replace('偏阳','+-')
                        sub_value = sub_value.replace('P','+')
                        sub_value = sub_value.replace('p','+')
                        sub_value = sub_value.replace('N','-')
                        sub_value = sub_value.replace('IV','4')
                        sub_value = sub_value.replace('V','5')
                        sub_value = sub_value.replace('III','3')
                        sub_value = sub_value.replace('II','2')
                        sub_value = sub_value.replace('I','1')
                        sub_value = sub_value.replace('。','.')
                        sub_value = sub_value.strip('.')
                        sub_value = sub_value.strip('°')
                        sub_value = sub_value.strip('%')
                        sub_value = sub_value.strip('度')
                        sub_value = sub_value.strip('mmol/L')
                        sub_value = sub_value.strip('自述不查')
                        sub_value = sub_value.strip('详见报告单')
                        sub_value = sub_value.strip('/')
                        sub_value = sub_value.strip('标本已退检')
                        sub_value = sub_value.strip()
                        sub_value = sub_value.replace('..','.')
                        sub_value = sub_value.replace('＜','<')
                        sub_value = sub_value.replace('＞','>')
                        sub_value = sub_value.replace('>','')
                        sub_value = sub_value.replace('<','')
                        sub_value = sub_value.replace('＋','+')
                        sub_value = sub_value.replace('－','-')
                        sub_value = sub_value.replace('iv','４')
                        sub_value = sub_value.replace('iii','3')
                        sub_value = sub_value.replace('ii','2')
                        sub_value = sub_value.replace('i','1')
                        sub_value = sub_value.replace('Ⅲ','3')
                        sub_value = sub_value.replace('Ⅱ','2')
                        sub_value = sub_value.replace('Ⅰ','1')
                        sub_value = sub_value.replace('Ⅳ','4')
                        sub_value = sub_value.replace('中度','2')
                        row.append(sub_value)

    physical_data[j] = row
# Out:
# 2388 列缺失值超过阈值
# (57298, 408)
# HBox(children=(IntProgress(value=0, max=408), HTML(value='')))
# 数值特征数目97
# 字符特征数目311
# HBox(children=(IntProgress(value=0, max=408), HTML(value='')))

# %% [markdown]
# # 6 特征转换为数值

# %%
# 手动确定一些肉眼观测过的列为数值列和无关列
customized_num_column = ['100005', '100007', '10002', '10003' ,'1107', '1115', '1117', '1127', '1345',
 '1814', '1845', '190', '2174', '2403', '2404', '2405', '2406', '2420', '269007',
 '269008', '269009', '269010', '269011', '269014', '269015', '269016', '269017',
 '269018', '269019', '269020', '269021', '269022', '269023', '269024', '269025',
 '315', '316', '317', '319', '33', '34', '37', '39', '669001', '809009', '979004',
 '979005', '979006', '979008', '979009', '979011', '979013', '979014', '979015',
 '979016', '979017', '979018', '979019', '979020', '979021', '979022', '979023',
 '0422', '0423', '0977', '1103', '1106', '1303', '1304', '1305', '1308' ,'1313',
 '1314', '1315', '1316', '1330', '139', '143', '1474', '155', '1840', '1850', '191',
 '192', '2231', '2501', '269003', '269013', '300036']
customized_drop_column = ['0121', '0122', '0123', '0202', '0203', '0206', '0207' ,'0208', '0209', '0210',
 '0212', '0215', '0216', '0225', '0403', '0405', '0406', '0413', '0420', '0421',
 '0425', '0426', '0427', '0428', '0429', '0430', '0434', '0435', '0436', '0501',
 '0503', '0509', '0516', '0702', '0703', '0705', '0706', '0707', '0709', '0912',
 '0947', '0949', '0954', '0972', '0973', '0974', '0975', '0980', '0983', '0984',
 '0985', '0987', '100014', '1001', '1102', '1301', '1329', '1402', '31', '312', '313']

# %%
column_name = list(physical_data.columns.values)
numerical_feature = []
for item in tqdm(column_name):
    try:
        physical_data[item] = physical_data[item].astype('float16')
        numerical_feature.append(item)
    except:
        continue
str_feature = []
for item in column_name:
    if item not in numerical_feature:
        str_feature.append(item)
print('数值特征数目%d'% (len(numerical_feature)))
print('字符特征数目%d'%(len(str_feature)))

# 1 原始数值
new_df = pd.DataFrame()
for i in numerical_feature:
    new_df[i] = physical_data.loc[:,i]
print(new_df.shape)

# 2 新增数值
num_func = customized_num_column
num_func = [x for x in num_func if x not in numerical_feature]
for i in num_func:
    name = i
    new_column = []
    for value in physical_data.loc[:,name]:
        try:
            new_column.append(float(value))
        except:
            value = value.replace('-','')
            value = value.replace('+','')
            if '-' in value:
                try:
                    t = np.mean(map(float,value.split('-')))
                    new_column.append(t)
                    print(t)
                except:
                    new_column.append(np.NaN)
            else:
                try:
                    new_column.append(float(value))
                except:
                    new_column.append(np.NaN)
    try:
        map(float,new_column)
    except:
        print('bad feature',i)
    new_df[name] = new_column
print(new_df.shape)

negative_word = ['+','慢性','肿大','痛疼','压痛','出现异常','不正常','差','不佳','欠均匀','坏死','异常','显示不清','扩张','增大',
                '增厚','痛','轻度','重度','晚期','偏高','偏低','不清晰','畸形','先天性','瘘管','囊肿','湿疹','肥大','糖尿病','糜烂','出血','充血','咽炎','建议医院及时就诊','建议及时就诊','过长','过短','建议进一步','手术治疗','观察',
                '血肿','紊乱','增生','炎','疑似','确诊','结节','疝','糖尿病','瘤','水肿','+-''失常','建议复查']     
positive_word = ['未见明显异常','未见异常','-','正常','健康','未触及','未检出','弃查','未查','未见异','无特殊','未及','整齐',
                '齐','单字无','无重大手术','无过敏史','无叩痛','无特殊记载','未检','活动自如','阴性','良好','及格','无扩张',
                '未显示','未探及','未闻及']
negative_sign = ['无','未发现','未出现','没有','不','未见']

# ３增加等级数值
drop = customized_drop_column
numerical_feature = numerical_feature+num_func
column_name = list(physical_data.columns.values)
remain_str = [x for x in column_name if x not in numerical_feature  and x not in drop]
print('剩余字符特征%d'%len(remain_str))
huayan_feature = []
nume = 0
char = 0
for item in tqdm(remain_str):
    this_column = physical_data.loc[:,item]
    new_column = []
    num_value = 0
    grade_value = 0
    other = 0
    for value in this_column:
        value = str(value)
        if value == 'nan':
            continue
        else:
            try:
                float(value)
                num_value+=1
            except:
                if '-' in value or '+' in value:
                    grade_value+=1
                else:
                    other+=1
    total = other+num_value+grade_value
    # 转数字列
    if num_value/total>0.6:
        nume+=1
        for value in this_column:
            value = str(value)
            if value == 'nan':
                new_column.append(np.NaN)
            else:
                try:
                    float(value)
                    new_column.append(abs(float(value)))
                except:
                    if '+' in value:
                        if new_column == []:
                            c = [1]
                        else:
                            c = new_column
                        new_column.append(np.log(max(c)+1))
                    elif '-' in value:
                        if new_column == []:
                            c = [0]
                        else:
                            c = new_column
                        new_column.append(min(c))
                    else:
                        new_column.append(np.NaN)
        new_df[item] = new_column
    # 转等级列
    elif grade_value/total>0.6:
        char+=1
        huayan_feature.append(item)
        for value in this_column:
            value = str(value)
            if value == 'nan':
                new_column.append(np.NaN)
            elif value in ['少','少见','低','较低','少量']:
                new_column.append(-0.5)
            elif '多' in value or '高'in value or '强' in value:
                new_column.append(1)
            elif '+' in value or '-' in value:
                plus = value.count('+')
                minus = 0-value.count('-')*0.5
                new_column.append(plus+minus)
            else:
                new_column.append(np.NaN)
        new_df[item] = new_column

    # 转正常、异常二分类　
    else:
        positive = 0
        negative = 0
        for value in this_column:
            value = str(value)
            if value == 'nan':
                new_column.append(np.NaN)
            else:
                be_pos = True
                for word in negative_word:
                    if word in value:
                        value = value.replace(word, 'haha')
                        be_neg = True
                        for n in negative_sign:
                            if n in value:
                                be_neg = False
                                break
                        if be_neg:
                            new_column.append(1)
                            be_pos = False
                            break
                        else:
                            new_column.append(0)
                            be_pos = False
                            break
                if be_pos:
                    if '无'==value:
                        new_column.append(0)
                    else:
                        pos_sign = False
                        for word in positive_word:
                            if word in value:
                                value = value.replace(word, 'haha')
                                be_pos = True
                                for n in negative_sign:
                                    if n in value:
                                        be_pos = False
                                        break
                                if be_pos:
                                    new_column.append(0)
                                    pos_sign = True
                                    break
                                else:
                                    new_column.append(1)
                                    pos_sign = True
                                    break
                        if not pos_sign:
                            new_column.append(1)
        new_df[item] = new_column
print(new_df.shape)
print(nume,char)
# print(len(new_column)-physical_data.shape[0])
# Out:
# HBox(children=(IntProgress(value=0, max=408), HTML(value='')))
# 数值特征数目170
# 字符特征数目238
# (57298, 170)
# (57298, 194)
# 剩余字符特征154
# HBox(children=(IntProgress(value=0, max=154), HTML(value='')))
# (57298, 348)
# 58 23

# %%
raw_data = pd.read_pickle('../data/physical_data.pkl')
# 加入化验指标
huayan_df = pd.DataFrame()
for item in huayan_feature:
    huayan_df[item] = raw_data.loc[:,item]
new_df['huayan']=len(huayan_feature)-huayan_df.isnull().sum(axis=1)

# temp_df
column_name = raw_data.columns
drop_column = []
valid_column = []
valid_df = pd.DataFrame()
for f in column_name:
    if raw_data.loc[:,f].isnull().sum()>56000:
        drop_column.append(f)
    else:
        valid_column.append(f)
print('%d 列缺失值超过阈值'%len(drop_column))

# temp_df
temp_df = pd.DataFrame()
str_feature_temp = [x for x in raw_data.columns if x not in new_df.columns and x in valid_column]
print(len(str_feature_temp))
for item in str_feature_temp:
    temp_df[item] = raw_data.loc[:,item]
    
# 某些特征指标
new_name = {'肝炎':['肝炎'],'高血压':['高血压','血压偏高'],'高血脂':['高血脂','血脂偏高','高尿酸'],'血管':['动脉硬化','弹性减弱'
       '动脉轻度硬化','血管狭窄','动脉重度减弱','血管堵塞']}
x = temp_df.shape[0]
y = temp_df.shape[1]
print(x)
print(new_df.shape)
for item,values in new_name.items():
    new_column = []
    for i in tqdm(range(x)):
        c = 0
        for j in range(y):
            v = raw_data.iloc[i,j]
            if isinstance(v,str):
                for sub_name in values:
                    if sub_name in v:
                        c = 1
                        break
                if c == 1:
                    break
        new_column.append(c)
    new_df[item] = new_column
# Out:
# 2303 列缺失值超过阈值
# 145
# 57298
# (57298, 349)
# HBox(children=(IntProgress(value=0, max=57298), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=57298), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=57298), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=57298), HTML(value='')))

# %%
new_df.to_pickle('../data/train_data.pkl')

# %% [markdown]
# # ７特征提取完毕，训练

# %%
physical_data = pd.read_pickle('../data/train_data.pkl')
index = np.load('../data/index.npy')
physical_data.index = index
# 去除inf数据
j = 0
for column in tqdm(physical_data.columns):
    new_column = []
    for i in range(len(index)):
        value = physical_data.iloc[i,j]
        if str(value) == 'inf':
            max_value = [x if str(x) not in ['inf','nan'] else 0 for x in physical_data.loc[:,column]]
            new_column.append(np.max(max_value)*1.5)
        else:
            new_column.append(value)
    physical_data[column] = new_column
    j+=1
# Out:
# HBox(children=(IntProgress(value=0, max=353), HTML(value='')))

# %%
# 裁剪数据，并生成五对训练测试集
clip = {'收缩压':[60,250],'舒张压':[40,200],'血清甘油三酯':[0.1,20],
        '血清高密度脂蛋白':[0.15,4.78],'血清低密度脂蛋白':[0.15,11.54]}
colume_name = train.columns[1::]
data_set = []
for item in colume_name:
    index = []
    y = []
    print(item)
    for i in range(len(train)):
        value = train.ix[i,item]
        try:
            c = float(value)
            if c<0:
                c = abs(c)
            if c>0:
                if c<clip[item][0]:
                    c = clip[item][0]
                elif c>clip[item][1]:
                    c = clip[item][1]
                index.append(train.ix[i,'vid'])
                y.append(np.log(c+1))
        except:
            continue
    assert len(y) == len(index)
    data_set.append((index,y))    
gc.collect()
# Out:
# 收缩压
# /home/zhu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # This is added back by InteractiveShellApp.init_path()
# 舒张压
# 血清甘油三酯
# 血清高密度脂蛋白
# 血清低密度脂蛋白
# 4376

# %%
# %%time
# # for xgb test
# temp = []
# def cal_loss(X,y,alpha):
#     # for xgb test 
#     param = {}
#     #param['objective'] = 'multi:softprob'
#     param['eta'] = 0.1  
#     param['max_depth'] = 7
#     param['silent'] = 1  
#     #param['num_class'] = 2
#     # param['scale_pos_weight'] = 3
#     param['learning_rate'] = alpha
#     param['nthread'] = 8
#     #param['colsample_bytree'] = 0.8
#     param['objective'] = 'reg:linear'
#     param['eval_metric'] = 'rmse'
#     param['alpha'] = 3
#     param['lambda'] = 1
#     param['subsample'] = 0.8
#     num_round = 5000
#     kfolds = 5
#     result = np.zeros((kfolds,len(test)))
#     i = 0
#     kf = KFold(n_splits=kfolds,shuffle=True,random_state=2017)
#     for train_index,test_index in kf.split(X):
#         X_train, X_test = X[train_index], X[test_index]
#         y_train, y_test = y[train_index], y[test_index]
#         xg_train = xgb.DMatrix(X_train, label = y_train) 
#         xg_test = xgb.DMatrix(X_test, label = y_test) 
#         watchlist = [(xg_train, 'train'), (xg_test, 'val')]
#         bst = xgb.train(param, xg_train, num_round, watchlist, early_stopping_rounds = 100)
#         y_ = bst.predict(xg_test)
#         loss = pinche(y_,y_test)
#         temp.append(loss)
#         print('loss ',loss)
# #         print(y_)
# #         print(y_test)
#         #result[i,:]=bst.predict(real_test)
#         i += 1
#         break
    
#     # result = result.mean(axis = 0)
#     return loss,bst
# def pinche(y,y_):
#     loss = 0
#     for (a,b) in zip(y,y_):
#         loss += np.square(a-b)
#     loss = loss/len(y)
#     return loss
# # for test
# loss = 0
# temp = []
# alpha = [0.03,0.03,0.01,0.03,0.03]
# droped = []
# for i in tqdm(range(5)):
# #     X = physical_data.loc[data_set[i][0],:].values
# #     y = np.array(data_set[i][1])
#     # 计算相关性
    
#     X = physical_data.loc[data_set[i][0],:]
#     y = pd.Series(data_set[i][1],index=X.index)
#     relation = []
#     drop_name = []
#     for item in X.columns:
#         dest_column = X.loc[:,item]
#         valid_index = dest_column[dest_column.isnull().values==False].index
#         p = np.corrcoef(dest_column[valid_index],y[valid_index])[0,1]
#         if str(p)=='nan':
#             drop_name.append(item)
#             continue
#         relation.append(p)
#         if abs(p)<0.001:
#             drop_name.append(item)
#     new_name = []
#     for name in X.columns:
#         if name not in drop_name:
#             new_name.append(name)
#     droped.append(len(drop_name))
#     X = X.loc[:,new_name].values
#     loss_,bst = cal_loss(X,y,alpha[i])
#     loss += loss_
    
# #     print(loss)
# #     break
# print('综合误差',loss/5)
# print(temp)
# print(droped)
#  [730,700,3000,1900,1500] 5folds
#综合误差 0.0283987430225
#[0.014185164660642451, 0.017427459798813025, 0.070259258661747953, 0.010533861670180705, 0.029587970321256648]
#[1000,800,3400,1600,1000]
#综合误差 0.0284058652739
#[0.014108574382090414, 0.017440564477319388, 0.070309427643018216, 0.010475003189642052, 0.029695756677422185]
#[911,1015,3400,2000,1000]
#综合误差 0.0279969044026 扩充了０／１数据
#[0.013857185028851752, 0.017187679117757895, 0.069640120188378729, 0.010260849633918358, 0.029038688044271885]
#[1112,942,4000,1300,1600/1500]
#综合误差 0.0282251169377
#[0.013928837700233097, 0.017835912899625734, 0.068658421347080126, 0.01077727989589701, 0.029925132845582743]
#
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3159: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3093: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3093: RuntimeWarning: invalid value encountered in multiply
#   c *= 1. / np.float64(fact)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3167: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3168: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# [0]	train-rmse:4.20644	val-rmse:4.20499
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [1]	train-rmse:4.08038	val-rmse:4.07893
# [2]	train-rmse:3.95814	val-rmse:3.9567
# [3]	train-rmse:3.83957	val-rmse:3.83816
# [4]	train-rmse:3.72456	val-rmse:3.72314
# [5]	train-rmse:3.61301	val-rmse:3.6116
# [6]	train-rmse:3.50477	val-rmse:3.50337
# [7]	train-rmse:3.39979	val-rmse:3.39839
# [8]	train-rmse:3.29798	val-rmse:3.29657
# [9]	train-rmse:3.19924	val-rmse:3.19785
# [10]	train-rmse:3.10347	val-rmse:3.10209
# [11]	train-rmse:3.01056	val-rmse:3.00918
# [12]	train-rmse:2.92045	val-rmse:2.91907
# [13]	train-rmse:2.83303	val-rmse:2.83166
# [14]	train-rmse:2.74826	val-rmse:2.7469
# [15]	train-rmse:2.66604	val-rmse:2.66469
# [16]	train-rmse:2.58629	val-rmse:2.58494
# [17]	train-rmse:2.50893	val-rmse:2.50759
# [18]	train-rmse:2.43389	val-rmse:2.43257
# [19]	train-rmse:2.36108	val-rmse:2.35976
# [20]	train-rmse:2.29049	val-rmse:2.28919
# [21]	train-rmse:2.22201	val-rmse:2.22072
# [22]	train-rmse:2.15561	val-rmse:2.15433
# [23]	train-rmse:2.09121	val-rmse:2.08995
# [24]	train-rmse:2.02874	val-rmse:2.02749
# [25]	train-rmse:1.96817	val-rmse:1.96692
# [26]	train-rmse:1.9094	val-rmse:1.90816
# [27]	train-rmse:1.8524	val-rmse:1.85117
# [28]	train-rmse:1.79713	val-rmse:1.79592
# [29]	train-rmse:1.74352	val-rmse:1.74232
# [30]	train-rmse:1.69154	val-rmse:1.69035
# [31]	train-rmse:1.64111	val-rmse:1.63993
# [32]	train-rmse:1.59224	val-rmse:1.59108
# [33]	train-rmse:1.54481	val-rmse:1.54366
# [34]	train-rmse:1.49882	val-rmse:1.49769
# [35]	train-rmse:1.45422	val-rmse:1.45308
# [36]	train-rmse:1.41098	val-rmse:1.40985
# [37]	train-rmse:1.36905	val-rmse:1.36793
# [38]	train-rmse:1.32839	val-rmse:1.32728
# [39]	train-rmse:1.28893	val-rmse:1.28782
# [40]	train-rmse:1.25069	val-rmse:1.24959
# [41]	train-rmse:1.21362	val-rmse:1.21252
# [42]	train-rmse:1.17765	val-rmse:1.17658
# [43]	train-rmse:1.14278	val-rmse:1.1417
# [44]	train-rmse:1.10897	val-rmse:1.10791
# [45]	train-rmse:1.07617	val-rmse:1.07512
# [46]	train-rmse:1.0444	val-rmse:1.04335
# [47]	train-rmse:1.01358	val-rmse:1.01254
# [48]	train-rmse:0.983683	val-rmse:0.982647
# [49]	train-rmse:0.954718	val-rmse:0.953687
# [50]	train-rmse:0.926608	val-rmse:0.925579
# [51]	train-rmse:0.899396	val-rmse:0.898375
# [52]	train-rmse:0.872998	val-rmse:0.871984
# [53]	train-rmse:0.847409	val-rmse:0.846401
# [54]	train-rmse:0.822593	val-rmse:0.821605
# [55]	train-rmse:0.798528	val-rmse:0.797547
# [56]	train-rmse:0.775239	val-rmse:0.774266
# [57]	train-rmse:0.752664	val-rmse:0.751696
# [58]	train-rmse:0.730756	val-rmse:0.729794
# [59]	train-rmse:0.709533	val-rmse:0.708594
# [60]	train-rmse:0.688966	val-rmse:0.688033
# [61]	train-rmse:0.669042	val-rmse:0.668118
# [62]	train-rmse:0.649739	val-rmse:0.648816
# [63]	train-rmse:0.631053	val-rmse:0.63014
# [64]	train-rmse:0.612947	val-rmse:0.612046
# [65]	train-rmse:0.595409	val-rmse:0.594518
# [66]	train-rmse:0.578383	val-rmse:0.577501
# [67]	train-rmse:0.561915	val-rmse:0.561042
# [68]	train-rmse:0.545968	val-rmse:0.545112
# [69]	train-rmse:0.530523	val-rmse:0.529697
# [70]	train-rmse:0.515526	val-rmse:0.514714
# [71]	train-rmse:0.501017	val-rmse:0.500234
# [72]	train-rmse:0.487007	val-rmse:0.486258
# [73]	train-rmse:0.473413	val-rmse:0.472687
# [74]	train-rmse:0.460275	val-rmse:0.459578
# [75]	train-rmse:0.447532	val-rmse:0.446855
# [76]	train-rmse:0.435194	val-rmse:0.434558
# [77]	train-rmse:0.423292	val-rmse:0.422677
# [78]	train-rmse:0.411768	val-rmse:0.411192
# [79]	train-rmse:0.400612	val-rmse:0.400055
# [80]	train-rmse:0.38984	val-rmse:0.389307
# [81]	train-rmse:0.379411	val-rmse:0.378909
# [82]	train-rmse:0.36933	val-rmse:0.368867
# [83]	train-rmse:0.359572	val-rmse:0.359131
# [84]	train-rmse:0.350129	val-rmse:0.349716
# [85]	train-rmse:0.341015	val-rmse:0.340641
# [86]	train-rmse:0.332201	val-rmse:0.331864
# [87]	train-rmse:0.323668	val-rmse:0.323354
# [88]	train-rmse:0.315464	val-rmse:0.315194
# [89]	train-rmse:0.307521	val-rmse:0.307277
# [90]	train-rmse:0.299859	val-rmse:0.299653
# [91]	train-rmse:0.29247	val-rmse:0.292298
# [92]	train-rmse:0.285335	val-rmse:0.285194
# [93]	train-rmse:0.27845	val-rmse:0.278351
# [94]	train-rmse:0.271784	val-rmse:0.271724
# [95]	train-rmse:0.26539	val-rmse:0.265373
# [96]	train-rmse:0.259219	val-rmse:0.259237
# [97]	train-rmse:0.253289	val-rmse:0.253342
# [98]	train-rmse:0.247558	val-rmse:0.247653
# [99]	train-rmse:0.242043	val-rmse:0.242181
# [100]	train-rmse:0.236735	val-rmse:0.236906
# [101]	train-rmse:0.231619	val-rmse:0.231845
# [102]	train-rmse:0.226721	val-rmse:0.227006
# [103]	train-rmse:0.221983	val-rmse:0.222334
# [104]	train-rmse:0.217423	val-rmse:0.217828
# [105]	train-rmse:0.213053	val-rmse:0.213505
# [106]	train-rmse:0.208841	val-rmse:0.209336
# [107]	train-rmse:0.20478	val-rmse:0.205331
# [108]	train-rmse:0.200909	val-rmse:0.201516
# [109]	train-rmse:0.197203	val-rmse:0.197864
# [110]	train-rmse:0.193629	val-rmse:0.194355
# [111]	train-rmse:0.190192	val-rmse:0.19098
# [112]	train-rmse:0.18691	val-rmse:0.187767
# [113]	train-rmse:0.18376	val-rmse:0.184679
# [114]	train-rmse:0.180745	val-rmse:0.181728
# [115]	train-rmse:0.177845	val-rmse:0.17889
# [116]	train-rmse:0.175094	val-rmse:0.176191
# [117]	train-rmse:0.172439	val-rmse:0.173608
# [118]	train-rmse:0.169892	val-rmse:0.171128
# [119]	train-rmse:0.167452	val-rmse:0.168755
# [120]	train-rmse:0.165151	val-rmse:0.166502
# [121]	train-rmse:0.162922	val-rmse:0.164337
# [122]	train-rmse:0.160819	val-rmse:0.1623
# [123]	train-rmse:0.158799	val-rmse:0.16035
# [124]	train-rmse:0.156885	val-rmse:0.158509
# [125]	train-rmse:0.155043	val-rmse:0.156737
# [126]	train-rmse:0.153287	val-rmse:0.155036
# [127]	train-rmse:0.151607	val-rmse:0.153402
# [128]	train-rmse:0.150001	val-rmse:0.151871
# [129]	train-rmse:0.148487	val-rmse:0.150407
# [130]	train-rmse:0.14702	val-rmse:0.148995
# [131]	train-rmse:0.145631	val-rmse:0.147675
# [132]	train-rmse:0.144305	val-rmse:0.146415
# [133]	train-rmse:0.143054	val-rmse:0.145236
# [134]	train-rmse:0.141848	val-rmse:0.144097
# [135]	train-rmse:0.140698	val-rmse:0.143016
# [136]	train-rmse:0.139616	val-rmse:0.142008
# [137]	train-rmse:0.138568	val-rmse:0.141017
# [138]	train-rmse:0.137568	val-rmse:0.140082
# [139]	train-rmse:0.136618	val-rmse:0.139204
# [140]	train-rmse:0.135701	val-rmse:0.138366
# [141]	train-rmse:0.134828	val-rmse:0.137558
# [142]	train-rmse:0.134015	val-rmse:0.136808
# [143]	train-rmse:0.133235	val-rmse:0.136086
# [144]	train-rmse:0.132483	val-rmse:0.135394
# [145]	train-rmse:0.131768	val-rmse:0.134737
# [146]	train-rmse:0.131082	val-rmse:0.134109
# [147]	train-rmse:0.130433	val-rmse:0.133517
# [148]	train-rmse:0.12982	val-rmse:0.132976
# [149]	train-rmse:0.129212	val-rmse:0.132427
# [150]	train-rmse:0.128646	val-rmse:0.13192
# [151]	train-rmse:0.128111	val-rmse:0.13143
# [152]	train-rmse:0.127599	val-rmse:0.130982
# [153]	train-rmse:0.127109	val-rmse:0.130562
# [154]	train-rmse:0.126643	val-rmse:0.130148
# [155]	train-rmse:0.12619	val-rmse:0.129746
# [156]	train-rmse:0.125765	val-rmse:0.129375
# [157]	train-rmse:0.12536	val-rmse:0.129016
# [158]	train-rmse:0.124963	val-rmse:0.128681
# [159]	train-rmse:0.124596	val-rmse:0.128359
# [160]	train-rmse:0.124238	val-rmse:0.128061
# [161]	train-rmse:0.123885	val-rmse:0.127764
# [162]	train-rmse:0.123571	val-rmse:0.127497
# [163]	train-rmse:0.12326	val-rmse:0.127238
# [164]	train-rmse:0.122971	val-rmse:0.126989
# [165]	train-rmse:0.122676	val-rmse:0.126756
# [166]	train-rmse:0.122392	val-rmse:0.126538
# [167]	train-rmse:0.122123	val-rmse:0.126331
# [168]	train-rmse:0.121847	val-rmse:0.126103
# [169]	train-rmse:0.121606	val-rmse:0.125908
# [170]	train-rmse:0.121381	val-rmse:0.125711
# [171]	train-rmse:0.121138	val-rmse:0.125515
# [172]	train-rmse:0.120901	val-rmse:0.125336
# [173]	train-rmse:0.120681	val-rmse:0.12516
# [174]	train-rmse:0.120488	val-rmse:0.125005
# [175]	train-rmse:0.120301	val-rmse:0.124867
# [176]	train-rmse:0.120108	val-rmse:0.124718
# [177]	train-rmse:0.119933	val-rmse:0.12458
# [178]	train-rmse:0.119738	val-rmse:0.124447
# [179]	train-rmse:0.119569	val-rmse:0.124311
# [180]	train-rmse:0.119407	val-rmse:0.124198
# [181]	train-rmse:0.119243	val-rmse:0.124092
# [182]	train-rmse:0.11908	val-rmse:0.123972
# [183]	train-rmse:0.118927	val-rmse:0.123856
# [184]	train-rmse:0.118765	val-rmse:0.123756
# [185]	train-rmse:0.118617	val-rmse:0.12365
# [186]	train-rmse:0.118484	val-rmse:0.123562
# [187]	train-rmse:0.118358	val-rmse:0.123469
# [188]	train-rmse:0.118226	val-rmse:0.123368
# [189]	train-rmse:0.118091	val-rmse:0.12328
# [190]	train-rmse:0.117971	val-rmse:0.1232
# [191]	train-rmse:0.117856	val-rmse:0.123126
# [192]	train-rmse:0.117737	val-rmse:0.123045
# [193]	train-rmse:0.117627	val-rmse:0.122966
# [194]	train-rmse:0.11752	val-rmse:0.122891
# [195]	train-rmse:0.117412	val-rmse:0.122814
# [196]	train-rmse:0.117292	val-rmse:0.122732
# [197]	train-rmse:0.117197	val-rmse:0.122664
# [198]	train-rmse:0.117098	val-rmse:0.1226
# [199]	train-rmse:0.117005	val-rmse:0.12255
# [200]	train-rmse:0.11689	val-rmse:0.122491
# [201]	train-rmse:0.116792	val-rmse:0.12243
# [202]	train-rmse:0.11669	val-rmse:0.122384
# [203]	train-rmse:0.116611	val-rmse:0.122334
# [204]	train-rmse:0.116534	val-rmse:0.122293
# [205]	train-rmse:0.116437	val-rmse:0.122243
# [206]	train-rmse:0.116345	val-rmse:0.122178
# [207]	train-rmse:0.116255	val-rmse:0.122132
# [208]	train-rmse:0.116146	val-rmse:0.122077
# [209]	train-rmse:0.116055	val-rmse:0.122026
# [210]	train-rmse:0.115961	val-rmse:0.121982
# [211]	train-rmse:0.115865	val-rmse:0.121925
# [212]	train-rmse:0.115773	val-rmse:0.121883
# [213]	train-rmse:0.115695	val-rmse:0.121846
# [214]	train-rmse:0.115604	val-rmse:0.121802
# [215]	train-rmse:0.11553	val-rmse:0.121761
# [216]	train-rmse:0.11543	val-rmse:0.121718
# [217]	train-rmse:0.115354	val-rmse:0.121687
# [218]	train-rmse:0.115276	val-rmse:0.121659
# [219]	train-rmse:0.115214	val-rmse:0.121622
# [220]	train-rmse:0.115139	val-rmse:0.12159
# [221]	train-rmse:0.115075	val-rmse:0.12155
# [222]	train-rmse:0.11502	val-rmse:0.121525
# [223]	train-rmse:0.114937	val-rmse:0.121487
# [224]	train-rmse:0.114879	val-rmse:0.121458
# [225]	train-rmse:0.114801	val-rmse:0.121429
# [226]	train-rmse:0.114739	val-rmse:0.1214
# [227]	train-rmse:0.114675	val-rmse:0.121371
# [228]	train-rmse:0.114595	val-rmse:0.12134
# [229]	train-rmse:0.114529	val-rmse:0.121316
# [230]	train-rmse:0.114449	val-rmse:0.121284
# [231]	train-rmse:0.114369	val-rmse:0.121254
# [232]	train-rmse:0.114313	val-rmse:0.12123
# [233]	train-rmse:0.114249	val-rmse:0.121205
# [234]	train-rmse:0.114193	val-rmse:0.121178
# [235]	train-rmse:0.114121	val-rmse:0.121152
# [236]	train-rmse:0.114058	val-rmse:0.121132
# [237]	train-rmse:0.113985	val-rmse:0.121108
# [238]	train-rmse:0.113913	val-rmse:0.121081
# [239]	train-rmse:0.113834	val-rmse:0.121047
# [240]	train-rmse:0.113781	val-rmse:0.121019
# [241]	train-rmse:0.113725	val-rmse:0.120997
# [242]	train-rmse:0.113666	val-rmse:0.120978
# [243]	train-rmse:0.113598	val-rmse:0.120952
# [244]	train-rmse:0.113526	val-rmse:0.120927
# [245]	train-rmse:0.113471	val-rmse:0.120909
# [246]	train-rmse:0.113431	val-rmse:0.120887
# [247]	train-rmse:0.113379	val-rmse:0.120857
# [248]	train-rmse:0.113307	val-rmse:0.120833
# [249]	train-rmse:0.113272	val-rmse:0.120817
# [250]	train-rmse:0.11322	val-rmse:0.120807
# [251]	train-rmse:0.113159	val-rmse:0.120797
# [252]	train-rmse:0.113102	val-rmse:0.120786
# [253]	train-rmse:0.113057	val-rmse:0.120772
# [254]	train-rmse:0.112998	val-rmse:0.120751
# [255]	train-rmse:0.112931	val-rmse:0.120719
# [256]	train-rmse:0.112891	val-rmse:0.1207
# [257]	train-rmse:0.112845	val-rmse:0.120695
# [258]	train-rmse:0.112789	val-rmse:0.120673
# [259]	train-rmse:0.112739	val-rmse:0.120654
# [260]	train-rmse:0.112679	val-rmse:0.120626
# [261]	train-rmse:0.112618	val-rmse:0.120608
# [262]	train-rmse:0.112573	val-rmse:0.120599
# [263]	train-rmse:0.11253	val-rmse:0.120585
# [264]	train-rmse:0.11249	val-rmse:0.12057
# [265]	train-rmse:0.112428	val-rmse:0.12055
# [266]	train-rmse:0.112384	val-rmse:0.120538
# [267]	train-rmse:0.112342	val-rmse:0.120524
# [268]	train-rmse:0.112304	val-rmse:0.120511
# [269]	train-rmse:0.112256	val-rmse:0.120502
# [270]	train-rmse:0.112199	val-rmse:0.12049
# [271]	train-rmse:0.112151	val-rmse:0.120477
# [272]	train-rmse:0.112102	val-rmse:0.120464
# [273]	train-rmse:0.112048	val-rmse:0.120442
# [274]	train-rmse:0.11198	val-rmse:0.120423
# [275]	train-rmse:0.111938	val-rmse:0.120413
# [276]	train-rmse:0.111905	val-rmse:0.120404
# [277]	train-rmse:0.111853	val-rmse:0.120385
# [278]	train-rmse:0.111805	val-rmse:0.120369
# [279]	train-rmse:0.111759	val-rmse:0.120348
# [280]	train-rmse:0.11169	val-rmse:0.12032
# [281]	train-rmse:0.111651	val-rmse:0.120309
# [282]	train-rmse:0.111603	val-rmse:0.120298
# [283]	train-rmse:0.111564	val-rmse:0.120286
# [284]	train-rmse:0.111497	val-rmse:0.120257
# [285]	train-rmse:0.11145	val-rmse:0.120233
# [286]	train-rmse:0.111398	val-rmse:0.120213
# [287]	train-rmse:0.111359	val-rmse:0.1202
# [288]	train-rmse:0.111309	val-rmse:0.120189
# [289]	train-rmse:0.111259	val-rmse:0.120173
# [290]	train-rmse:0.111207	val-rmse:0.120166
# [291]	train-rmse:0.111161	val-rmse:0.120148
# [292]	train-rmse:0.111129	val-rmse:0.120144
# [293]	train-rmse:0.111074	val-rmse:0.120124
# [294]	train-rmse:0.111039	val-rmse:0.120118
# [295]	train-rmse:0.11099	val-rmse:0.120106
# [296]	train-rmse:0.110941	val-rmse:0.120092
# [297]	train-rmse:0.110905	val-rmse:0.120082
# [298]	train-rmse:0.110851	val-rmse:0.120074
# [299]	train-rmse:0.110819	val-rmse:0.120064
# [300]	train-rmse:0.110776	val-rmse:0.120055
# [301]	train-rmse:0.110737	val-rmse:0.120049
# [302]	train-rmse:0.110682	val-rmse:0.120035
# [303]	train-rmse:0.110639	val-rmse:0.120021
# [304]	train-rmse:0.110595	val-rmse:0.120009
# [305]	train-rmse:0.11056	val-rmse:0.119998
# [306]	train-rmse:0.110515	val-rmse:0.119989
# [307]	train-rmse:0.110468	val-rmse:0.119973
# [308]	train-rmse:0.110433	val-rmse:0.119959
# [309]	train-rmse:0.11038	val-rmse:0.119947
# [310]	train-rmse:0.110344	val-rmse:0.119936
# [311]	train-rmse:0.110293	val-rmse:0.119924
# [312]	train-rmse:0.110258	val-rmse:0.119917
# [313]	train-rmse:0.110197	val-rmse:0.1199
# [314]	train-rmse:0.110162	val-rmse:0.119888
# [315]	train-rmse:0.110118	val-rmse:0.119882
# [316]	train-rmse:0.110077	val-rmse:0.119873
# [317]	train-rmse:0.110034	val-rmse:0.119851
# [318]	train-rmse:0.110004	val-rmse:0.11984
# [319]	train-rmse:0.109976	val-rmse:0.119834
# [320]	train-rmse:0.109929	val-rmse:0.119823
# [321]	train-rmse:0.109887	val-rmse:0.11982
# [322]	train-rmse:0.10985	val-rmse:0.119816
# [323]	train-rmse:0.109816	val-rmse:0.11981
# [324]	train-rmse:0.10978	val-rmse:0.119799
# [325]	train-rmse:0.109744	val-rmse:0.119793
# [326]	train-rmse:0.109698	val-rmse:0.119787
# [327]	train-rmse:0.109657	val-rmse:0.119773
# [328]	train-rmse:0.109603	val-rmse:0.119753
# [329]	train-rmse:0.109572	val-rmse:0.119742
# [330]	train-rmse:0.109539	val-rmse:0.119726
# [331]	train-rmse:0.109483	val-rmse:0.119701
# [332]	train-rmse:0.109445	val-rmse:0.119692
# [333]	train-rmse:0.109404	val-rmse:0.119683
# [334]	train-rmse:0.10936	val-rmse:0.119674
# [335]	train-rmse:0.109314	val-rmse:0.119671
# [336]	train-rmse:0.109277	val-rmse:0.119662
# [337]	train-rmse:0.109228	val-rmse:0.119652
# [338]	train-rmse:0.109202	val-rmse:0.119645
# [339]	train-rmse:0.109151	val-rmse:0.119629
# [340]	train-rmse:0.109114	val-rmse:0.11962
# [341]	train-rmse:0.109086	val-rmse:0.119612
# [342]	train-rmse:0.109045	val-rmse:0.119608
# [343]	train-rmse:0.108992	val-rmse:0.119606
# [344]	train-rmse:0.108948	val-rmse:0.119595
# [345]	train-rmse:0.108897	val-rmse:0.119584
# [346]	train-rmse:0.108848	val-rmse:0.119569
# [347]	train-rmse:0.108815	val-rmse:0.119563
# [348]	train-rmse:0.108761	val-rmse:0.119556
# [349]	train-rmse:0.108735	val-rmse:0.119555
# [350]	train-rmse:0.108699	val-rmse:0.119549
# [351]	train-rmse:0.108659	val-rmse:0.119548
# [352]	train-rmse:0.108621	val-rmse:0.119541
# [353]	train-rmse:0.108586	val-rmse:0.119527
# [354]	train-rmse:0.108551	val-rmse:0.119522
# [355]	train-rmse:0.108519	val-rmse:0.11951
# [356]	train-rmse:0.108472	val-rmse:0.119497
# [357]	train-rmse:0.108451	val-rmse:0.119493
# [358]	train-rmse:0.108416	val-rmse:0.119484
# [359]	train-rmse:0.108364	val-rmse:0.119476
# [360]	train-rmse:0.108327	val-rmse:0.119471
# [361]	train-rmse:0.108283	val-rmse:0.119458
# [362]	train-rmse:0.10824	val-rmse:0.119452
# [363]	train-rmse:0.108211	val-rmse:0.119444
# [364]	train-rmse:0.108174	val-rmse:0.11943
# [365]	train-rmse:0.108144	val-rmse:0.119413
# [366]	train-rmse:0.108115	val-rmse:0.119405
# [367]	train-rmse:0.108094	val-rmse:0.119406
# [368]	train-rmse:0.10807	val-rmse:0.119403
# [369]	train-rmse:0.108021	val-rmse:0.119391
# [370]	train-rmse:0.107984	val-rmse:0.119389
# [371]	train-rmse:0.107932	val-rmse:0.119384
# [372]	train-rmse:0.1079	val-rmse:0.119373
# [373]	train-rmse:0.107865	val-rmse:0.119361
# [374]	train-rmse:0.107815	val-rmse:0.119352
# [375]	train-rmse:0.107771	val-rmse:0.119344
# [376]	train-rmse:0.107732	val-rmse:0.119337
# [377]	train-rmse:0.107706	val-rmse:0.119321
# [378]	train-rmse:0.107662	val-rmse:0.11931
# [379]	train-rmse:0.107616	val-rmse:0.119301
# [380]	train-rmse:0.107578	val-rmse:0.119293
# [381]	train-rmse:0.107554	val-rmse:0.119287
# [382]	train-rmse:0.107531	val-rmse:0.119284
# [383]	train-rmse:0.107479	val-rmse:0.119273
# [384]	train-rmse:0.107434	val-rmse:0.119264
# [385]	train-rmse:0.107404	val-rmse:0.11926
# [386]	train-rmse:0.107374	val-rmse:0.119253
# [387]	train-rmse:0.107344	val-rmse:0.119245
# [388]	train-rmse:0.107318	val-rmse:0.119241
# [389]	train-rmse:0.107286	val-rmse:0.119236
# [390]	train-rmse:0.107244	val-rmse:0.119223
# [391]	train-rmse:0.10721	val-rmse:0.119207
# [392]	train-rmse:0.107173	val-rmse:0.119204
# [393]	train-rmse:0.107141	val-rmse:0.1192
# [394]	train-rmse:0.107115	val-rmse:0.119199
# [395]	train-rmse:0.10708	val-rmse:0.119194
# [396]	train-rmse:0.107047	val-rmse:0.119184
# [397]	train-rmse:0.107012	val-rmse:0.119183
# [398]	train-rmse:0.106972	val-rmse:0.119171
# [399]	train-rmse:0.106941	val-rmse:0.11917
# [400]	train-rmse:0.106913	val-rmse:0.119166
# [401]	train-rmse:0.106888	val-rmse:0.119162
# [402]	train-rmse:0.106855	val-rmse:0.119155
# [403]	train-rmse:0.106823	val-rmse:0.11915
# [404]	train-rmse:0.106795	val-rmse:0.119143
# [405]	train-rmse:0.106768	val-rmse:0.119131
# [406]	train-rmse:0.106738	val-rmse:0.119122
# [407]	train-rmse:0.106701	val-rmse:0.119113
# [408]	train-rmse:0.106673	val-rmse:0.119116
# [409]	train-rmse:0.106645	val-rmse:0.11911
# [410]	train-rmse:0.106621	val-rmse:0.119105
# [411]	train-rmse:0.106588	val-rmse:0.119101
# [412]	train-rmse:0.106554	val-rmse:0.119101
# [413]	train-rmse:0.10652	val-rmse:0.119096
# [414]	train-rmse:0.106495	val-rmse:0.119099
# [415]	train-rmse:0.106468	val-rmse:0.119098
# [416]	train-rmse:0.106437	val-rmse:0.119097
# [417]	train-rmse:0.106395	val-rmse:0.119094
# [418]	train-rmse:0.106363	val-rmse:0.119088
# [419]	train-rmse:0.106337	val-rmse:0.119079
# [420]	train-rmse:0.106315	val-rmse:0.119075
# [421]	train-rmse:0.106286	val-rmse:0.11907
# [422]	train-rmse:0.106256	val-rmse:0.11906
# [423]	train-rmse:0.10623	val-rmse:0.119056
# [424]	train-rmse:0.106202	val-rmse:0.119051
# [425]	train-rmse:0.106164	val-rmse:0.11905
# [426]	train-rmse:0.106137	val-rmse:0.119043
# [427]	train-rmse:0.106105	val-rmse:0.119041
# [428]	train-rmse:0.106072	val-rmse:0.119037
# [429]	train-rmse:0.106045	val-rmse:0.11903
# [430]	train-rmse:0.106013	val-rmse:0.119027
# [431]	train-rmse:0.105971	val-rmse:0.119021
# [432]	train-rmse:0.105933	val-rmse:0.119012
# [433]	train-rmse:0.10591	val-rmse:0.119004
# [434]	train-rmse:0.105884	val-rmse:0.118998
# [435]	train-rmse:0.105844	val-rmse:0.118993
# [436]	train-rmse:0.105815	val-rmse:0.118983
# [437]	train-rmse:0.105788	val-rmse:0.118984
# [438]	train-rmse:0.105757	val-rmse:0.118984
# [439]	train-rmse:0.105725	val-rmse:0.118977
# [440]	train-rmse:0.105691	val-rmse:0.118975
# [441]	train-rmse:0.105659	val-rmse:0.118973
# [442]	train-rmse:0.105637	val-rmse:0.118972
# [443]	train-rmse:0.1056	val-rmse:0.118973
# [444]	train-rmse:0.105578	val-rmse:0.118965
# [445]	train-rmse:0.105551	val-rmse:0.118956
# [446]	train-rmse:0.105515	val-rmse:0.118951
# [447]	train-rmse:0.105487	val-rmse:0.11895
# [448]	train-rmse:0.105446	val-rmse:0.118954
# [449]	train-rmse:0.105417	val-rmse:0.11895
# [450]	train-rmse:0.105384	val-rmse:0.118946
# [451]	train-rmse:0.105343	val-rmse:0.118937
# [452]	train-rmse:0.105315	val-rmse:0.118933
# [453]	train-rmse:0.105274	val-rmse:0.118928
# [454]	train-rmse:0.105241	val-rmse:0.11892
# [455]	train-rmse:0.105212	val-rmse:0.118919
# [456]	train-rmse:0.105185	val-rmse:0.118914
# [457]	train-rmse:0.10515	val-rmse:0.118909
# [458]	train-rmse:0.105131	val-rmse:0.118905
# [459]	train-rmse:0.105101	val-rmse:0.118908
# [460]	train-rmse:0.105079	val-rmse:0.118901
# [461]	train-rmse:0.105045	val-rmse:0.1189
# [462]	train-rmse:0.105011	val-rmse:0.118894
# [463]	train-rmse:0.104975	val-rmse:0.118886
# [464]	train-rmse:0.104951	val-rmse:0.11888
# [465]	train-rmse:0.104928	val-rmse:0.118872
# [466]	train-rmse:0.10489	val-rmse:0.118869
# [467]	train-rmse:0.104852	val-rmse:0.118867
# [468]	train-rmse:0.104821	val-rmse:0.118865
# [469]	train-rmse:0.104784	val-rmse:0.118862
# [470]	train-rmse:0.104767	val-rmse:0.118861
# [471]	train-rmse:0.104727	val-rmse:0.118863
# [472]	train-rmse:0.104692	val-rmse:0.118857
# [473]	train-rmse:0.104665	val-rmse:0.118853
# [474]	train-rmse:0.10464	val-rmse:0.118851
# [475]	train-rmse:0.104603	val-rmse:0.118849
# [476]	train-rmse:0.10458	val-rmse:0.118844
# [477]	train-rmse:0.104549	val-rmse:0.11884
# [478]	train-rmse:0.104502	val-rmse:0.118829
# [479]	train-rmse:0.10448	val-rmse:0.118827
# [480]	train-rmse:0.104451	val-rmse:0.118827
# [481]	train-rmse:0.104428	val-rmse:0.118825
# [482]	train-rmse:0.10438	val-rmse:0.118819
# [483]	train-rmse:0.10435	val-rmse:0.118813
# [484]	train-rmse:0.104326	val-rmse:0.118812
# [485]	train-rmse:0.104283	val-rmse:0.118809
# [486]	train-rmse:0.10425	val-rmse:0.118813
# [487]	train-rmse:0.104215	val-rmse:0.118808
# [488]	train-rmse:0.104183	val-rmse:0.118802
# [489]	train-rmse:0.104161	val-rmse:0.118798
# [490]	train-rmse:0.104135	val-rmse:0.118793
# [491]	train-rmse:0.104105	val-rmse:0.118791
# [492]	train-rmse:0.104072	val-rmse:0.118788
# [493]	train-rmse:0.104051	val-rmse:0.118785
# [494]	train-rmse:0.10403	val-rmse:0.11878
# [495]	train-rmse:0.103995	val-rmse:0.118782
# [496]	train-rmse:0.103972	val-rmse:0.118779
# [497]	train-rmse:0.103943	val-rmse:0.118771
# [498]	train-rmse:0.103919	val-rmse:0.118769
# [499]	train-rmse:0.103884	val-rmse:0.11877
# [500]	train-rmse:0.103851	val-rmse:0.118761
# [501]	train-rmse:0.103816	val-rmse:0.118754
# [502]	train-rmse:0.103797	val-rmse:0.118751
# [503]	train-rmse:0.103772	val-rmse:0.118747
# [504]	train-rmse:0.103732	val-rmse:0.118751
# [505]	train-rmse:0.10371	val-rmse:0.118744
# [506]	train-rmse:0.103674	val-rmse:0.118732
# [507]	train-rmse:0.103646	val-rmse:0.118732
# [508]	train-rmse:0.10361	val-rmse:0.118719
# [509]	train-rmse:0.10358	val-rmse:0.11872
# [510]	train-rmse:0.103555	val-rmse:0.118718
# [511]	train-rmse:0.10353	val-rmse:0.118715
# [512]	train-rmse:0.103504	val-rmse:0.118718
# [513]	train-rmse:0.103485	val-rmse:0.118715
# [514]	train-rmse:0.10346	val-rmse:0.118709
# [515]	train-rmse:0.103427	val-rmse:0.118704
# [516]	train-rmse:0.103405	val-rmse:0.118702
# [517]	train-rmse:0.10338	val-rmse:0.1187
# [518]	train-rmse:0.103345	val-rmse:0.118698
# [519]	train-rmse:0.103323	val-rmse:0.118695
# [520]	train-rmse:0.103289	val-rmse:0.118688
# [521]	train-rmse:0.103268	val-rmse:0.118687
# [522]	train-rmse:0.103249	val-rmse:0.118684
# [523]	train-rmse:0.103226	val-rmse:0.118681
# [524]	train-rmse:0.103205	val-rmse:0.11868
# [525]	train-rmse:0.10318	val-rmse:0.118677
# [526]	train-rmse:0.103162	val-rmse:0.118678
# [527]	train-rmse:0.103128	val-rmse:0.118682
# [528]	train-rmse:0.103107	val-rmse:0.11868
# [529]	train-rmse:0.103084	val-rmse:0.118675
# [530]	train-rmse:0.103047	val-rmse:0.118669
# [531]	train-rmse:0.103024	val-rmse:0.118663
# [532]	train-rmse:0.103001	val-rmse:0.118658
# [533]	train-rmse:0.102969	val-rmse:0.118649
# [534]	train-rmse:0.102934	val-rmse:0.118649
# [535]	train-rmse:0.102913	val-rmse:0.118651
# [536]	train-rmse:0.10288	val-rmse:0.118649
# [537]	train-rmse:0.10285	val-rmse:0.118652
# [538]	train-rmse:0.102825	val-rmse:0.118652
# [539]	train-rmse:0.102803	val-rmse:0.118643
# [540]	train-rmse:0.102772	val-rmse:0.118639
# [541]	train-rmse:0.102745	val-rmse:0.118638
# [542]	train-rmse:0.102691	val-rmse:0.118621
# [543]	train-rmse:0.102674	val-rmse:0.118619
# [544]	train-rmse:0.102636	val-rmse:0.118616
# [545]	train-rmse:0.102609	val-rmse:0.118615
# [546]	train-rmse:0.102578	val-rmse:0.118612
# [547]	train-rmse:0.10256	val-rmse:0.118606
# [548]	train-rmse:0.102537	val-rmse:0.118602
# [549]	train-rmse:0.102516	val-rmse:0.1186
# [550]	train-rmse:0.102497	val-rmse:0.118607
# [551]	train-rmse:0.102478	val-rmse:0.118599
# [552]	train-rmse:0.102447	val-rmse:0.118599
# [553]	train-rmse:0.102414	val-rmse:0.1186
# [554]	train-rmse:0.102377	val-rmse:0.118596
# [555]	train-rmse:0.10235	val-rmse:0.118592
# [556]	train-rmse:0.102322	val-rmse:0.118587
# [557]	train-rmse:0.102291	val-rmse:0.118574
# [558]	train-rmse:0.102257	val-rmse:0.118571
# [559]	train-rmse:0.102224	val-rmse:0.118566
# [560]	train-rmse:0.1022	val-rmse:0.118563
# [561]	train-rmse:0.102175	val-rmse:0.118559
# [562]	train-rmse:0.102141	val-rmse:0.118564
# [563]	train-rmse:0.102115	val-rmse:0.118559
# [564]	train-rmse:0.102094	val-rmse:0.118557
# [565]	train-rmse:0.102076	val-rmse:0.118556
# [566]	train-rmse:0.102049	val-rmse:0.118545
# [567]	train-rmse:0.102015	val-rmse:0.118543
# [568]	train-rmse:0.10199	val-rmse:0.118537
# [569]	train-rmse:0.101951	val-rmse:0.118533
# [570]	train-rmse:0.101917	val-rmse:0.118531
# [571]	train-rmse:0.101896	val-rmse:0.118533
# [572]	train-rmse:0.101866	val-rmse:0.118539
# [573]	train-rmse:0.101848	val-rmse:0.118537
# [574]	train-rmse:0.101822	val-rmse:0.118532
# [575]	train-rmse:0.101794	val-rmse:0.118527
# [576]	train-rmse:0.101771	val-rmse:0.118526
# [577]	train-rmse:0.101754	val-rmse:0.118522
# [578]	train-rmse:0.101738	val-rmse:0.118522
# [579]	train-rmse:0.101717	val-rmse:0.118524
# [580]	train-rmse:0.101686	val-rmse:0.118524
# [581]	train-rmse:0.101651	val-rmse:0.118521
# [582]	train-rmse:0.101622	val-rmse:0.118514
# [583]	train-rmse:0.101591	val-rmse:0.118505
# [584]	train-rmse:0.101571	val-rmse:0.118498
# [585]	train-rmse:0.101536	val-rmse:0.118487
# [586]	train-rmse:0.101506	val-rmse:0.118486
# [587]	train-rmse:0.101476	val-rmse:0.118485
# [588]	train-rmse:0.101446	val-rmse:0.118485
# [589]	train-rmse:0.101425	val-rmse:0.118486
# [590]	train-rmse:0.101406	val-rmse:0.118489
# [591]	train-rmse:0.101382	val-rmse:0.118481
# [592]	train-rmse:0.101348	val-rmse:0.118473
# [593]	train-rmse:0.101322	val-rmse:0.118472
# [594]	train-rmse:0.101291	val-rmse:0.118462
# [595]	train-rmse:0.101272	val-rmse:0.118461
# [596]	train-rmse:0.101255	val-rmse:0.11846
# [597]	train-rmse:0.101231	val-rmse:0.118456
# [598]	train-rmse:0.101207	val-rmse:0.118452
# [599]	train-rmse:0.101186	val-rmse:0.118453
# [600]	train-rmse:0.101165	val-rmse:0.118447
# [601]	train-rmse:0.101138	val-rmse:0.118446
# [602]	train-rmse:0.101108	val-rmse:0.118449
# [603]	train-rmse:0.10107	val-rmse:0.118444
# [604]	train-rmse:0.101041	val-rmse:0.11844
# [605]	train-rmse:0.101018	val-rmse:0.11844
# [606]	train-rmse:0.10099	val-rmse:0.118441
# [607]	train-rmse:0.100955	val-rmse:0.118444
# [608]	train-rmse:0.100933	val-rmse:0.118439
# [609]	train-rmse:0.100898	val-rmse:0.118435
# [610]	train-rmse:0.100881	val-rmse:0.118433
# [611]	train-rmse:0.100858	val-rmse:0.118429
# [612]	train-rmse:0.100826	val-rmse:0.118428
# [613]	train-rmse:0.100804	val-rmse:0.118427
# [614]	train-rmse:0.100788	val-rmse:0.118427
# [615]	train-rmse:0.100764	val-rmse:0.118427
# [616]	train-rmse:0.10073	val-rmse:0.118425
# [617]	train-rmse:0.100706	val-rmse:0.118428
# [618]	train-rmse:0.100669	val-rmse:0.118426
# [619]	train-rmse:0.100652	val-rmse:0.118423
# [620]	train-rmse:0.10063	val-rmse:0.118414
# [621]	train-rmse:0.100588	val-rmse:0.118414
# [622]	train-rmse:0.100566	val-rmse:0.118413
# [623]	train-rmse:0.100542	val-rmse:0.118412
# [624]	train-rmse:0.100511	val-rmse:0.118401
# [625]	train-rmse:0.100492	val-rmse:0.118399
# [626]	train-rmse:0.100469	val-rmse:0.118401
# [627]	train-rmse:0.100444	val-rmse:0.1184
# [628]	train-rmse:0.100424	val-rmse:0.118398
# [629]	train-rmse:0.100405	val-rmse:0.118398
# [630]	train-rmse:0.100383	val-rmse:0.118398
# [631]	train-rmse:0.100349	val-rmse:0.118397
# [632]	train-rmse:0.100314	val-rmse:0.118401
# [633]	train-rmse:0.100283	val-rmse:0.118396
# [634]	train-rmse:0.100257	val-rmse:0.1184
# [635]	train-rmse:0.100234	val-rmse:0.118394
# [636]	train-rmse:0.100213	val-rmse:0.118394
# [637]	train-rmse:0.10019	val-rmse:0.118396
# [638]	train-rmse:0.100163	val-rmse:0.118395
# [639]	train-rmse:0.100139	val-rmse:0.118391
# [640]	train-rmse:0.100121	val-rmse:0.118383
# [641]	train-rmse:0.100103	val-rmse:0.118379
# [642]	train-rmse:0.100081	val-rmse:0.118379
# [643]	train-rmse:0.100058	val-rmse:0.118376
# [644]	train-rmse:0.100038	val-rmse:0.118376
# [645]	train-rmse:0.10002	val-rmse:0.118376
# [646]	train-rmse:0.099998	val-rmse:0.118372
# [647]	train-rmse:0.099978	val-rmse:0.118374
# [648]	train-rmse:0.099948	val-rmse:0.118373
# [649]	train-rmse:0.099926	val-rmse:0.11837
# [650]	train-rmse:0.099899	val-rmse:0.118373
# [651]	train-rmse:0.09988	val-rmse:0.118368
# [652]	train-rmse:0.099846	val-rmse:0.118365
# [653]	train-rmse:0.099822	val-rmse:0.118368
# [654]	train-rmse:0.099792	val-rmse:0.118366
# [655]	train-rmse:0.099761	val-rmse:0.118351
# [656]	train-rmse:0.099737	val-rmse:0.118352
# [657]	train-rmse:0.099712	val-rmse:0.118351
# [658]	train-rmse:0.099689	val-rmse:0.118351
# [659]	train-rmse:0.099669	val-rmse:0.118352
# [660]	train-rmse:0.099648	val-rmse:0.118351
# [661]	train-rmse:0.099629	val-rmse:0.11835
# [662]	train-rmse:0.099602	val-rmse:0.118347
# [663]	train-rmse:0.099583	val-rmse:0.118348
# [664]	train-rmse:0.099556	val-rmse:0.118346
# [665]	train-rmse:0.099529	val-rmse:0.118347
# [666]	train-rmse:0.099514	val-rmse:0.118346
# [667]	train-rmse:0.099487	val-rmse:0.11834
# [668]	train-rmse:0.09947	val-rmse:0.118341
# [669]	train-rmse:0.099438	val-rmse:0.118334
# [670]	train-rmse:0.09941	val-rmse:0.118329
# [671]	train-rmse:0.099393	val-rmse:0.118329
# [672]	train-rmse:0.099374	val-rmse:0.11833
# [673]	train-rmse:0.099353	val-rmse:0.118328
# [674]	train-rmse:0.099324	val-rmse:0.118329
# [675]	train-rmse:0.09929	val-rmse:0.118324
# [676]	train-rmse:0.099261	val-rmse:0.118321
# [677]	train-rmse:0.099242	val-rmse:0.11832
# [678]	train-rmse:0.099221	val-rmse:0.118321
# [679]	train-rmse:0.099202	val-rmse:0.118324
# [680]	train-rmse:0.099187	val-rmse:0.118326
# [681]	train-rmse:0.099156	val-rmse:0.118328
# [682]	train-rmse:0.099132	val-rmse:0.118326
# [683]	train-rmse:0.099092	val-rmse:0.118324
# [684]	train-rmse:0.099077	val-rmse:0.118323
# [685]	train-rmse:0.099052	val-rmse:0.11832
# [686]	train-rmse:0.099021	val-rmse:0.118319
# [687]	train-rmse:0.099003	val-rmse:0.118315
# [688]	train-rmse:0.098975	val-rmse:0.11831
# [689]	train-rmse:0.098954	val-rmse:0.118306
# [690]	train-rmse:0.098935	val-rmse:0.118305
# [691]	train-rmse:0.098901	val-rmse:0.118297
# [692]	train-rmse:0.098866	val-rmse:0.118294
# [693]	train-rmse:0.098839	val-rmse:0.118287
# [694]	train-rmse:0.098811	val-rmse:0.118284
# [695]	train-rmse:0.098792	val-rmse:0.118285
# [696]	train-rmse:0.098769	val-rmse:0.118285
# [697]	train-rmse:0.098743	val-rmse:0.118281
# [698]	train-rmse:0.098724	val-rmse:0.118278
# [699]	train-rmse:0.098703	val-rmse:0.118281
# [700]	train-rmse:0.098675	val-rmse:0.118277
# [701]	train-rmse:0.098654	val-rmse:0.118271
# [702]	train-rmse:0.098623	val-rmse:0.118266
# [703]	train-rmse:0.098604	val-rmse:0.118267
# [704]	train-rmse:0.098585	val-rmse:0.11826
# [705]	train-rmse:0.098566	val-rmse:0.118258
# [706]	train-rmse:0.098551	val-rmse:0.118258
# [707]	train-rmse:0.098518	val-rmse:0.118257
# [708]	train-rmse:0.098498	val-rmse:0.118253
# [709]	train-rmse:0.098477	val-rmse:0.11825
# [710]	train-rmse:0.098453	val-rmse:0.118247
# [711]	train-rmse:0.098427	val-rmse:0.118247
# [712]	train-rmse:0.0984	val-rmse:0.118249
# [713]	train-rmse:0.098369	val-rmse:0.118246
# [714]	train-rmse:0.098343	val-rmse:0.118246
# [715]	train-rmse:0.098315	val-rmse:0.118242
# [716]	train-rmse:0.098294	val-rmse:0.118242
# [717]	train-rmse:0.098258	val-rmse:0.118234
# [718]	train-rmse:0.098229	val-rmse:0.118237
# [719]	train-rmse:0.098209	val-rmse:0.11824
# [720]	train-rmse:0.098183	val-rmse:0.118239
# [721]	train-rmse:0.09815	val-rmse:0.118237
# [722]	train-rmse:0.098123	val-rmse:0.118227
# [723]	train-rmse:0.098094	val-rmse:0.118226
# [724]	train-rmse:0.098068	val-rmse:0.118224
# [725]	train-rmse:0.098044	val-rmse:0.118226
# [726]	train-rmse:0.098012	val-rmse:0.118224
# [727]	train-rmse:0.097988	val-rmse:0.118223
# [728]	train-rmse:0.097963	val-rmse:0.118218
# [729]	train-rmse:0.097938	val-rmse:0.118214
# [730]	train-rmse:0.097921	val-rmse:0.118213
# [731]	train-rmse:0.097904	val-rmse:0.118217
# [732]	train-rmse:0.097873	val-rmse:0.118213
# [733]	train-rmse:0.097851	val-rmse:0.118211
# [734]	train-rmse:0.097823	val-rmse:0.118211
# [735]	train-rmse:0.097792	val-rmse:0.118211
# [736]	train-rmse:0.097765	val-rmse:0.11821
# [737]	train-rmse:0.097737	val-rmse:0.118204
# [738]	train-rmse:0.097716	val-rmse:0.118201
# [739]	train-rmse:0.097697	val-rmse:0.118202
# [740]	train-rmse:0.097681	val-rmse:0.118198
# [741]	train-rmse:0.09765	val-rmse:0.118194
# [742]	train-rmse:0.097629	val-rmse:0.118193
# [743]	train-rmse:0.097601	val-rmse:0.118191
# [744]	train-rmse:0.097583	val-rmse:0.118196
# [745]	train-rmse:0.097559	val-rmse:0.118193
# [746]	train-rmse:0.097535	val-rmse:0.118194
# [747]	train-rmse:0.097518	val-rmse:0.118194
# [748]	train-rmse:0.097488	val-rmse:0.11819
# [749]	train-rmse:0.097468	val-rmse:0.118187
# [750]	train-rmse:0.097447	val-rmse:0.118186
# [751]	train-rmse:0.097416	val-rmse:0.118185
# [752]	train-rmse:0.097388	val-rmse:0.118188
# [753]	train-rmse:0.097363	val-rmse:0.118194
# [754]	train-rmse:0.097345	val-rmse:0.118193
# [755]	train-rmse:0.09733	val-rmse:0.118192
# [756]	train-rmse:0.097307	val-rmse:0.118191
# [757]	train-rmse:0.097279	val-rmse:0.11819
# [758]	train-rmse:0.097259	val-rmse:0.11819
# [759]	train-rmse:0.097238	val-rmse:0.11819
# [760]	train-rmse:0.097213	val-rmse:0.118188
# [761]	train-rmse:0.097185	val-rmse:0.118185
# [762]	train-rmse:0.097156	val-rmse:0.118185
# [763]	train-rmse:0.097124	val-rmse:0.118186
# [764]	train-rmse:0.097093	val-rmse:0.118186
# [765]	train-rmse:0.097066	val-rmse:0.118181
# [766]	train-rmse:0.097041	val-rmse:0.118174
# [767]	train-rmse:0.097021	val-rmse:0.118178
# [768]	train-rmse:0.097002	val-rmse:0.118178
# [769]	train-rmse:0.096972	val-rmse:0.118178
# [770]	train-rmse:0.096949	val-rmse:0.11818
# [771]	train-rmse:0.096925	val-rmse:0.118182
# [772]	train-rmse:0.0969	val-rmse:0.118178
# [773]	train-rmse:0.096887	val-rmse:0.118179
# [774]	train-rmse:0.096864	val-rmse:0.118174
# [775]	train-rmse:0.09684	val-rmse:0.118174
# [776]	train-rmse:0.096815	val-rmse:0.118173
# [777]	train-rmse:0.096791	val-rmse:0.118174
# [778]	train-rmse:0.096764	val-rmse:0.118171
# [779]	train-rmse:0.096741	val-rmse:0.118163
# [780]	train-rmse:0.096719	val-rmse:0.118161
# [781]	train-rmse:0.096695	val-rmse:0.118156
# [782]	train-rmse:0.096674	val-rmse:0.118157
# [783]	train-rmse:0.096644	val-rmse:0.118158
# [784]	train-rmse:0.096618	val-rmse:0.118155
# [785]	train-rmse:0.096589	val-rmse:0.118153
# [786]	train-rmse:0.096565	val-rmse:0.118149
# [787]	train-rmse:0.096545	val-rmse:0.118149
# [788]	train-rmse:0.096519	val-rmse:0.118145
# [789]	train-rmse:0.096504	val-rmse:0.118146
# [790]	train-rmse:0.096483	val-rmse:0.118147
# [791]	train-rmse:0.096449	val-rmse:0.118149
# [792]	train-rmse:0.096423	val-rmse:0.118147
# [793]	train-rmse:0.096393	val-rmse:0.118141
# [794]	train-rmse:0.096374	val-rmse:0.118138
# [795]	train-rmse:0.096344	val-rmse:0.118136
# [796]	train-rmse:0.09632	val-rmse:0.118131
# [797]	train-rmse:0.096305	val-rmse:0.118135
# [798]	train-rmse:0.096279	val-rmse:0.118138
# [799]	train-rmse:0.096259	val-rmse:0.118133
# [800]	train-rmse:0.096239	val-rmse:0.118134
# [801]	train-rmse:0.096205	val-rmse:0.118134
# [802]	train-rmse:0.096179	val-rmse:0.118131
# [803]	train-rmse:0.096143	val-rmse:0.118126
# [804]	train-rmse:0.096125	val-rmse:0.118128
# [805]	train-rmse:0.096092	val-rmse:0.118124
# [806]	train-rmse:0.096071	val-rmse:0.118127
# [807]	train-rmse:0.096044	val-rmse:0.118122
# [808]	train-rmse:0.096013	val-rmse:0.11812
# [809]	train-rmse:0.095993	val-rmse:0.118125
# [810]	train-rmse:0.095971	val-rmse:0.11812
# [811]	train-rmse:0.095958	val-rmse:0.118119
# [812]	train-rmse:0.095931	val-rmse:0.118115
# [813]	train-rmse:0.095901	val-rmse:0.118115
# [814]	train-rmse:0.095878	val-rmse:0.118111
# [815]	train-rmse:0.095851	val-rmse:0.118115
# [816]	train-rmse:0.095833	val-rmse:0.11811
# [817]	train-rmse:0.095801	val-rmse:0.118112
# [818]	train-rmse:0.095784	val-rmse:0.118106
# [819]	train-rmse:0.095755	val-rmse:0.118108
# [820]	train-rmse:0.095735	val-rmse:0.118102
# [821]	train-rmse:0.095705	val-rmse:0.118103
# [822]	train-rmse:0.09568	val-rmse:0.118101
# [823]	train-rmse:0.095659	val-rmse:0.118097
# [824]	train-rmse:0.095642	val-rmse:0.118098
# [825]	train-rmse:0.095627	val-rmse:0.118098
# [826]	train-rmse:0.095597	val-rmse:0.118101
# [827]	train-rmse:0.095568	val-rmse:0.118098
# [828]	train-rmse:0.095537	val-rmse:0.118098
# [829]	train-rmse:0.095512	val-rmse:0.118097
# [830]	train-rmse:0.095487	val-rmse:0.118095
# [831]	train-rmse:0.095464	val-rmse:0.11809
# [832]	train-rmse:0.095439	val-rmse:0.118094
# [833]	train-rmse:0.095419	val-rmse:0.118097
# [834]	train-rmse:0.095401	val-rmse:0.118092
# [835]	train-rmse:0.095371	val-rmse:0.118086
# [836]	train-rmse:0.095359	val-rmse:0.118084
# [837]	train-rmse:0.095336	val-rmse:0.118084
# [838]	train-rmse:0.095304	val-rmse:0.118082
# [839]	train-rmse:0.095289	val-rmse:0.118081
# [840]	train-rmse:0.095266	val-rmse:0.118079
# [841]	train-rmse:0.095244	val-rmse:0.11807
# [842]	train-rmse:0.095225	val-rmse:0.118074
# [843]	train-rmse:0.09519	val-rmse:0.118078
# [844]	train-rmse:0.095168	val-rmse:0.118073
# [845]	train-rmse:0.095144	val-rmse:0.118078
# [846]	train-rmse:0.095124	val-rmse:0.118074
# [847]	train-rmse:0.095102	val-rmse:0.118072
# [848]	train-rmse:0.095081	val-rmse:0.118077
# [849]	train-rmse:0.095063	val-rmse:0.118077
# [850]	train-rmse:0.095045	val-rmse:0.118073
# [851]	train-rmse:0.095029	val-rmse:0.118073
# [852]	train-rmse:0.095005	val-rmse:0.11807
# [853]	train-rmse:0.094986	val-rmse:0.118069
# [854]	train-rmse:0.094962	val-rmse:0.118072
# [855]	train-rmse:0.094933	val-rmse:0.118072
# [856]	train-rmse:0.094902	val-rmse:0.118068
# [857]	train-rmse:0.094875	val-rmse:0.118067
# [858]	train-rmse:0.09486	val-rmse:0.118066
# [859]	train-rmse:0.094842	val-rmse:0.118064
# [860]	train-rmse:0.094825	val-rmse:0.118066
# [861]	train-rmse:0.094805	val-rmse:0.118061
# [862]	train-rmse:0.094779	val-rmse:0.118064
# [863]	train-rmse:0.094752	val-rmse:0.118064
# [864]	train-rmse:0.094724	val-rmse:0.118061
# [865]	train-rmse:0.094704	val-rmse:0.118062
# [866]	train-rmse:0.094678	val-rmse:0.11806
# [867]	train-rmse:0.094653	val-rmse:0.118061
# [868]	train-rmse:0.09463	val-rmse:0.118062
# [869]	train-rmse:0.094613	val-rmse:0.11806
# [870]	train-rmse:0.094586	val-rmse:0.118062
# [871]	train-rmse:0.094561	val-rmse:0.11806
# [872]	train-rmse:0.094529	val-rmse:0.118059
# [873]	train-rmse:0.094509	val-rmse:0.118059
# [874]	train-rmse:0.094474	val-rmse:0.118059
# [875]	train-rmse:0.094448	val-rmse:0.118055
# [876]	train-rmse:0.094434	val-rmse:0.118053
# [877]	train-rmse:0.094408	val-rmse:0.118052
# [878]	train-rmse:0.094384	val-rmse:0.118053
# [879]	train-rmse:0.094359	val-rmse:0.118058
# [880]	train-rmse:0.094341	val-rmse:0.118056
# [881]	train-rmse:0.094319	val-rmse:0.118053
# [882]	train-rmse:0.094295	val-rmse:0.118054
# [883]	train-rmse:0.094269	val-rmse:0.118056
# [884]	train-rmse:0.094248	val-rmse:0.118057
# [885]	train-rmse:0.094227	val-rmse:0.118059
# [886]	train-rmse:0.094202	val-rmse:0.118056
# [887]	train-rmse:0.094183	val-rmse:0.118056
# [888]	train-rmse:0.094157	val-rmse:0.118057
# [889]	train-rmse:0.094134	val-rmse:0.118054
# [890]	train-rmse:0.094118	val-rmse:0.11805
# [891]	train-rmse:0.094094	val-rmse:0.118047
# [892]	train-rmse:0.094071	val-rmse:0.118046
# [893]	train-rmse:0.094051	val-rmse:0.118048
# [894]	train-rmse:0.094037	val-rmse:0.11805
# [895]	train-rmse:0.094019	val-rmse:0.118048
# [896]	train-rmse:0.093999	val-rmse:0.118044
# [897]	train-rmse:0.093983	val-rmse:0.118048
# [898]	train-rmse:0.093968	val-rmse:0.118047
# [899]	train-rmse:0.093939	val-rmse:0.118049
# [900]	train-rmse:0.093915	val-rmse:0.118047
# [901]	train-rmse:0.093898	val-rmse:0.118044
# [902]	train-rmse:0.09388	val-rmse:0.118043
# [903]	train-rmse:0.093855	val-rmse:0.118038
# [904]	train-rmse:0.093834	val-rmse:0.118037
# [905]	train-rmse:0.09381	val-rmse:0.118037
# [906]	train-rmse:0.093794	val-rmse:0.118039
# [907]	train-rmse:0.093775	val-rmse:0.118036
# [908]	train-rmse:0.093756	val-rmse:0.118036
# [909]	train-rmse:0.093737	val-rmse:0.118034
# [910]	train-rmse:0.093722	val-rmse:0.118033
# [911]	train-rmse:0.093706	val-rmse:0.118034
# [912]	train-rmse:0.093692	val-rmse:0.118036
# [913]	train-rmse:0.093658	val-rmse:0.118047
# [914]	train-rmse:0.093634	val-rmse:0.118045
# [915]	train-rmse:0.093608	val-rmse:0.118045
# [916]	train-rmse:0.093577	val-rmse:0.118045
# [917]	train-rmse:0.093552	val-rmse:0.118046
# [918]	train-rmse:0.093527	val-rmse:0.118048
# [919]	train-rmse:0.093506	val-rmse:0.118047
# [920]	train-rmse:0.093489	val-rmse:0.118049
# [921]	train-rmse:0.093469	val-rmse:0.118053
# [922]	train-rmse:0.093453	val-rmse:0.118053
# [923]	train-rmse:0.093436	val-rmse:0.118047
# [924]	train-rmse:0.093414	val-rmse:0.118049
# [925]	train-rmse:0.093391	val-rmse:0.118051
# [926]	train-rmse:0.09337	val-rmse:0.118051
# [927]	train-rmse:0.093351	val-rmse:0.118052
# [928]	train-rmse:0.093326	val-rmse:0.118051
# [929]	train-rmse:0.093303	val-rmse:0.118056
# [930]	train-rmse:0.093286	val-rmse:0.118055
# [931]	train-rmse:0.09327	val-rmse:0.118055
# [932]	train-rmse:0.093244	val-rmse:0.118058
# [933]	train-rmse:0.093223	val-rmse:0.118063
# [934]	train-rmse:0.093213	val-rmse:0.11806
# [935]	train-rmse:0.093193	val-rmse:0.118062
# [936]	train-rmse:0.093165	val-rmse:0.11806
# [937]	train-rmse:0.093137	val-rmse:0.11806
# [938]	train-rmse:0.093112	val-rmse:0.118059
# [939]	train-rmse:0.093083	val-rmse:0.118064
# [940]	train-rmse:0.093055	val-rmse:0.118064
# [941]	train-rmse:0.093032	val-rmse:0.118068
# [942]	train-rmse:0.093015	val-rmse:0.118068
# [943]	train-rmse:0.092994	val-rmse:0.118067
# [944]	train-rmse:0.092976	val-rmse:0.118069
# [945]	train-rmse:0.092959	val-rmse:0.118072
# [946]	train-rmse:0.092937	val-rmse:0.118072
# [947]	train-rmse:0.092914	val-rmse:0.118069
# [948]	train-rmse:0.092899	val-rmse:0.118067
# [949]	train-rmse:0.092878	val-rmse:0.118068
# [950]	train-rmse:0.092861	val-rmse:0.118068
# [951]	train-rmse:0.092834	val-rmse:0.118069
# [952]	train-rmse:0.092814	val-rmse:0.118066
# [953]	train-rmse:0.092788	val-rmse:0.118064
# [954]	train-rmse:0.092761	val-rmse:0.11806
# [955]	train-rmse:0.092738	val-rmse:0.118059
# [956]	train-rmse:0.092726	val-rmse:0.11806
# [957]	train-rmse:0.0927	val-rmse:0.118063
# [958]	train-rmse:0.092683	val-rmse:0.118065
# [959]	train-rmse:0.092669	val-rmse:0.118066
# [960]	train-rmse:0.092646	val-rmse:0.118061
# [961]	train-rmse:0.092629	val-rmse:0.118064
# [962]	train-rmse:0.0926	val-rmse:0.118059
# [963]	train-rmse:0.092583	val-rmse:0.118059
# [964]	train-rmse:0.092555	val-rmse:0.118055
# [965]	train-rmse:0.092533	val-rmse:0.118059
# [966]	train-rmse:0.092518	val-rmse:0.118056
# [967]	train-rmse:0.0925	val-rmse:0.118054
# [968]	train-rmse:0.092482	val-rmse:0.118057
# [969]	train-rmse:0.09246	val-rmse:0.118056
# [970]	train-rmse:0.092435	val-rmse:0.118061
# [971]	train-rmse:0.092412	val-rmse:0.118062
# [972]	train-rmse:0.092392	val-rmse:0.118063
# [973]	train-rmse:0.092382	val-rmse:0.118063
# [974]	train-rmse:0.092356	val-rmse:0.118063
# [975]	train-rmse:0.092334	val-rmse:0.118061
# [976]	train-rmse:0.09231	val-rmse:0.11806
# [977]	train-rmse:0.092292	val-rmse:0.11806
# [978]	train-rmse:0.092271	val-rmse:0.118062
# [979]	train-rmse:0.092251	val-rmse:0.118064
# [980]	train-rmse:0.092227	val-rmse:0.118066
# [981]	train-rmse:0.092203	val-rmse:0.118063
# [982]	train-rmse:0.092184	val-rmse:0.118062
# [983]	train-rmse:0.092166	val-rmse:0.118065
# [984]	train-rmse:0.092147	val-rmse:0.118065
# [985]	train-rmse:0.092132	val-rmse:0.118063
# [986]	train-rmse:0.092118	val-rmse:0.118068
# [987]	train-rmse:0.092098	val-rmse:0.118069
# [988]	train-rmse:0.092075	val-rmse:0.118065
# [989]	train-rmse:0.09205	val-rmse:0.118067
# [990]	train-rmse:0.092033	val-rmse:0.118068
# [991]	train-rmse:0.092017	val-rmse:0.118069
# [992]	train-rmse:0.091987	val-rmse:0.118065
# [993]	train-rmse:0.091966	val-rmse:0.118067
# [994]	train-rmse:0.091942	val-rmse:0.118068
# [995]	train-rmse:0.091916	val-rmse:0.118071
# [996]	train-rmse:0.091891	val-rmse:0.118073
# [997]	train-rmse:0.091871	val-rmse:0.118072
# [998]	train-rmse:0.091855	val-rmse:0.118073
# [999]	train-rmse:0.091829	val-rmse:0.118076
# [1000]	train-rmse:0.091811	val-rmse:0.118076
# [1001]	train-rmse:0.091795	val-rmse:0.118079
# [1002]	train-rmse:0.091774	val-rmse:0.118084
# [1003]	train-rmse:0.091759	val-rmse:0.118083
# [1004]	train-rmse:0.091732	val-rmse:0.118082
# [1005]	train-rmse:0.091716	val-rmse:0.118079
# [1006]	train-rmse:0.091693	val-rmse:0.118079
# [1007]	train-rmse:0.091676	val-rmse:0.118081
# [1008]	train-rmse:0.091645	val-rmse:0.118078
# [1009]	train-rmse:0.091629	val-rmse:0.118075
# [1010]	train-rmse:0.09161	val-rmse:0.118075
# Stopping. Best iteration:
# [910]	train-rmse:0.093722	val-rmse:0.118033
#
# loss  0.0139417239775
# [0]	train-rmse:3.73253	val-rmse:3.7303
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [1]	train-rmse:3.62075	val-rmse:3.61853
# [2]	train-rmse:3.51232	val-rmse:3.51013
# [3]	train-rmse:3.40715	val-rmse:3.40497
# [4]	train-rmse:3.30515	val-rmse:3.303
# [5]	train-rmse:3.20622	val-rmse:3.20409
# [6]	train-rmse:3.11028	val-rmse:3.10815
# [7]	train-rmse:3.01719	val-rmse:3.01508
# [8]	train-rmse:2.92691	val-rmse:2.92482
# [9]	train-rmse:2.83934	val-rmse:2.83728
# [10]	train-rmse:2.75441	val-rmse:2.75237
# [11]	train-rmse:2.67201	val-rmse:2.66998
# [12]	train-rmse:2.5921	val-rmse:2.59008
# [13]	train-rmse:2.51463	val-rmse:2.51264
# [14]	train-rmse:2.43948	val-rmse:2.43751
# [15]	train-rmse:2.36658	val-rmse:2.36462
# [16]	train-rmse:2.29592	val-rmse:2.29398
# [17]	train-rmse:2.22736	val-rmse:2.22543
# [18]	train-rmse:2.16086	val-rmse:2.15895
# [19]	train-rmse:2.09638	val-rmse:2.09448
# [20]	train-rmse:2.03382	val-rmse:2.03193
# [21]	train-rmse:1.97312	val-rmse:1.97124
# [22]	train-rmse:1.91424	val-rmse:1.91238
# [23]	train-rmse:1.85718	val-rmse:1.85533
# [24]	train-rmse:1.80184	val-rmse:1.80001
# [25]	train-rmse:1.74815	val-rmse:1.74633
# [26]	train-rmse:1.69608	val-rmse:1.69428
# [27]	train-rmse:1.64559	val-rmse:1.6438
# [28]	train-rmse:1.59665	val-rmse:1.59487
# [29]	train-rmse:1.54916	val-rmse:1.5474
# [30]	train-rmse:1.50311	val-rmse:1.50135
# [31]	train-rmse:1.45847	val-rmse:1.45673
# [32]	train-rmse:1.41518	val-rmse:1.41346
# [33]	train-rmse:1.3732	val-rmse:1.3715
# [34]	train-rmse:1.33248	val-rmse:1.3308
# [35]	train-rmse:1.293	val-rmse:1.29133
# [36]	train-rmse:1.2547	val-rmse:1.25304
# [37]	train-rmse:1.21758	val-rmse:1.21593
# [38]	train-rmse:1.1816	val-rmse:1.17995
# [39]	train-rmse:1.14669	val-rmse:1.14507
# [40]	train-rmse:1.11285	val-rmse:1.11125
# [41]	train-rmse:1.08004	val-rmse:1.07846
# [42]	train-rmse:1.04824	val-rmse:1.04667
# [43]	train-rmse:1.01738	val-rmse:1.01582
# [44]	train-rmse:0.987484	val-rmse:0.985949
# [45]	train-rmse:0.958511	val-rmse:0.956993
# [46]	train-rmse:0.930395	val-rmse:0.928878
# [47]	train-rmse:0.90317	val-rmse:0.901678
# [48]	train-rmse:0.876779	val-rmse:0.875286
# [49]	train-rmse:0.851221	val-rmse:0.84976
# [50]	train-rmse:0.826424	val-rmse:0.824983
# [51]	train-rmse:0.802411	val-rmse:0.800978
# [52]	train-rmse:0.779118	val-rmse:0.777716
# [53]	train-rmse:0.756534	val-rmse:0.755154
# [54]	train-rmse:0.734686	val-rmse:0.733324
# [55]	train-rmse:0.71349	val-rmse:0.712134
# [56]	train-rmse:0.692947	val-rmse:0.691602
# ...
# [1218]	train-rmse:0.120205	val-rmse:0.173324
# [1219]	train-rmse:0.120172	val-rmse:0.173323
# [1220]	train-rmse:0.120144	val-rmse:0.173326
# [1221]	train-rmse:0.120125	val-rmse:0.173322
# [1222]	train-rmse:0.120098	val-rmse:0.173323
# [1223]	train-rmse:0.120068	val-rmse:0.17332
# [1224]	train-rmse:0.120034	val-rmse:0.173325
# [1225]	train-rmse:0.120001	val-rmse:0.173323
# [1226]	train-rmse:0.119967	val-rmse:0.17332
# [1227]	train-rmse:0.119931	val-rmse:0.17332
# [1228]	train-rmse:0.119894	val-rmse:0.173314
# [1229]	train-rmse:0.11985	val-rmse:0.173318
# [1230]	train-rmse:0.119823	val-rmse:0.173325
# [1231]	train-rmse:0.119797	val-rmse:0.173321
# [1232]	train-rmse:0.119761	val-rmse:0.17332
# [1233]	train-rmse:0.119726	val-rmse:0.173324
# [1234]	train-rmse:0.119698	val-rmse:0.17332
# [1235]	train-rmse:0.119666	val-rmse:0.173316
# [1236]	train-rmse:0.119641	val-rmse:0.173313
# [1237]	train-rmse:0.11961	val-rmse:0.173313
# [1238]	train-rmse:0.119568	val-rmse:0.173316
# [1239]	train-rmse:0.119524	val-rmse:0.173317
# [1240]	train-rmse:0.119492	val-rmse:0.173315
# [1241]	train-rmse:0.119456	val-rmse:0.173315
# [1242]	train-rmse:0.119415	val-rmse:0.173321
# [1243]	train-rmse:0.119387	val-rmse:0.173314
# [1244]	train-rmse:0.119348	val-rmse:0.173316
# [1245]	train-rmse:0.119319	val-rmse:0.173319
# [1246]	train-rmse:0.119287	val-rmse:0.173313
# [1247]	train-rmse:0.119258	val-rmse:0.173311
# [1248]	train-rmse:0.119212	val-rmse:0.173303
# [1249]	train-rmse:0.119198	val-rmse:0.173306
# [1250]	train-rmse:0.119158	val-rmse:0.173302
# [1251]	train-rmse:0.119125	val-rmse:0.17331
# [1252]	train-rmse:0.119082	val-rmse:0.173305
# [1253]	train-rmse:0.119055	val-rmse:0.173307
# [1254]	train-rmse:0.119029	val-rmse:0.173307
# [1255]	train-rmse:0.119003	val-rmse:0.173313
# [1256]	train-rmse:0.118977	val-rmse:0.173306
# [1257]	train-rmse:0.118939	val-rmse:0.173308
# [1258]	train-rmse:0.118908	val-rmse:0.173305
# [1259]	train-rmse:0.11887	val-rmse:0.173311
# [1260]	train-rmse:0.118828	val-rmse:0.173308
# [1261]	train-rmse:0.118801	val-rmse:0.173309
# [1262]	train-rmse:0.118769	val-rmse:0.173306
# [1263]	train-rmse:0.118742	val-rmse:0.173304
# [1264]	train-rmse:0.118712	val-rmse:0.173306
# [1265]	train-rmse:0.118674	val-rmse:0.173315
# [1266]	train-rmse:0.118643	val-rmse:0.173309
# [1267]	train-rmse:0.118606	val-rmse:0.173312
# [1268]	train-rmse:0.11858	val-rmse:0.173305
# [1269]	train-rmse:0.118546	val-rmse:0.173309
# [1270]	train-rmse:0.118526	val-rmse:0.173304
# [1271]	train-rmse:0.118495	val-rmse:0.173304
# [1272]	train-rmse:0.11846	val-rmse:0.173301
# [1273]	train-rmse:0.118437	val-rmse:0.173302
# [1274]	train-rmse:0.118405	val-rmse:0.173295
# [1275]	train-rmse:0.118381	val-rmse:0.173292
# [1276]	train-rmse:0.118338	val-rmse:0.173287
# [1277]	train-rmse:0.11831	val-rmse:0.173292
# [1278]	train-rmse:0.118275	val-rmse:0.173285
# [1279]	train-rmse:0.11825	val-rmse:0.173288
# [1280]	train-rmse:0.118215	val-rmse:0.173287
# [1281]	train-rmse:0.118175	val-rmse:0.173293
# [1282]	train-rmse:0.118141	val-rmse:0.173302
# [1283]	train-rmse:0.118112	val-rmse:0.173302
# [1284]	train-rmse:0.118076	val-rmse:0.1733
# [1285]	train-rmse:0.118045	val-rmse:0.173294
# [1286]	train-rmse:0.118009	val-rmse:0.173293
# [1287]	train-rmse:0.117984	val-rmse:0.173291
# [1288]	train-rmse:0.117954	val-rmse:0.173288
# [1289]	train-rmse:0.11793	val-rmse:0.173275
# [1290]	train-rmse:0.117891	val-rmse:0.17328
# [1291]	train-rmse:0.117855	val-rmse:0.173268
# [1292]	train-rmse:0.117815	val-rmse:0.173266
# [1293]	train-rmse:0.11779	val-rmse:0.173266
# [1294]	train-rmse:0.117769	val-rmse:0.173262
# [1295]	train-rmse:0.117743	val-rmse:0.173271
# [1296]	train-rmse:0.1177	val-rmse:0.173275
# [1297]	train-rmse:0.117664	val-rmse:0.173264
# [1298]	train-rmse:0.11764	val-rmse:0.17326
# [1299]	train-rmse:0.11761	val-rmse:0.173261
# [1300]	train-rmse:0.117585	val-rmse:0.173263
# [1301]	train-rmse:0.117547	val-rmse:0.173253
# [1302]	train-rmse:0.117517	val-rmse:0.173257
# [1303]	train-rmse:0.117483	val-rmse:0.173258
# [1304]	train-rmse:0.117449	val-rmse:0.17327
# [1305]	train-rmse:0.117418	val-rmse:0.173268
# [1306]	train-rmse:0.117392	val-rmse:0.173268
# [1307]	train-rmse:0.11735	val-rmse:0.173266
# [1308]	train-rmse:0.117312	val-rmse:0.173265
# [1309]	train-rmse:0.117279	val-rmse:0.173269
# [1310]	train-rmse:0.117257	val-rmse:0.173271
# [1311]	train-rmse:0.117224	val-rmse:0.173272
# [1312]	train-rmse:0.117201	val-rmse:0.173264
# [1313]	train-rmse:0.117182	val-rmse:0.173262
# [1314]	train-rmse:0.117145	val-rmse:0.173266
# [1315]	train-rmse:0.117117	val-rmse:0.173271
# [1316]	train-rmse:0.117086	val-rmse:0.173271
# [1317]	train-rmse:0.117042	val-rmse:0.173277
# [1318]	train-rmse:0.117015	val-rmse:0.173279
# [1319]	train-rmse:0.116993	val-rmse:0.17328
# [1320]	train-rmse:0.116953	val-rmse:0.173281
# [1321]	train-rmse:0.116928	val-rmse:0.173278
# [1322]	train-rmse:0.116896	val-rmse:0.173276
# [1323]	train-rmse:0.116859	val-rmse:0.173275
# [1324]	train-rmse:0.116834	val-rmse:0.173272
# [1325]	train-rmse:0.116797	val-rmse:0.173269
# [1326]	train-rmse:0.116764	val-rmse:0.173267
# [1327]	train-rmse:0.116728	val-rmse:0.173269
# [1328]	train-rmse:0.116703	val-rmse:0.17327
# [1329]	train-rmse:0.116675	val-rmse:0.173272
# [1330]	train-rmse:0.116652	val-rmse:0.17327
# [1331]	train-rmse:0.116619	val-rmse:0.173271
# [1332]	train-rmse:0.116597	val-rmse:0.173266
# [1333]	train-rmse:0.116554	val-rmse:0.173276
# [1334]	train-rmse:0.116512	val-rmse:0.173276
# [1335]	train-rmse:0.116492	val-rmse:0.173272
# [1336]	train-rmse:0.11646	val-rmse:0.173275
# [1337]	train-rmse:0.116434	val-rmse:0.173271
# [1338]	train-rmse:0.116395	val-rmse:0.173271
# [1339]	train-rmse:0.116372	val-rmse:0.173271
# [1340]	train-rmse:0.116351	val-rmse:0.173274
# [1341]	train-rmse:0.116325	val-rmse:0.173277
# [1342]	train-rmse:0.116295	val-rmse:0.17328
# [1343]	train-rmse:0.116264	val-rmse:0.173276
# [1344]	train-rmse:0.116222	val-rmse:0.173268
# [1345]	train-rmse:0.116192	val-rmse:0.173273
# [1346]	train-rmse:0.116154	val-rmse:0.17327
# [1347]	train-rmse:0.116118	val-rmse:0.173265
# [1348]	train-rmse:0.116089	val-rmse:0.173273
# [1349]	train-rmse:0.116067	val-rmse:0.173269
# [1350]	train-rmse:0.116037	val-rmse:0.173267
# [1351]	train-rmse:0.116	val-rmse:0.173276
# [1352]	train-rmse:0.115977	val-rmse:0.173274
# [1353]	train-rmse:0.115946	val-rmse:0.173278
# [1354]	train-rmse:0.115911	val-rmse:0.173269
# [1355]	train-rmse:0.115886	val-rmse:0.173267
# [1356]	train-rmse:0.11586	val-rmse:0.173268
# [1357]	train-rmse:0.115826	val-rmse:0.173274
# [1358]	train-rmse:0.115795	val-rmse:0.173275
# [1359]	train-rmse:0.115772	val-rmse:0.173276
# [1360]	train-rmse:0.115728	val-rmse:0.173276
# [1361]	train-rmse:0.115703	val-rmse:0.173274
# [1362]	train-rmse:0.115669	val-rmse:0.173266
# [1363]	train-rmse:0.115643	val-rmse:0.173261
# [1364]	train-rmse:0.11561	val-rmse:0.173272
# [1365]	train-rmse:0.11557	val-rmse:0.173273
# [1366]	train-rmse:0.115522	val-rmse:0.17327
# [1367]	train-rmse:0.115504	val-rmse:0.173271
# [1368]	train-rmse:0.115466	val-rmse:0.173271
# [1369]	train-rmse:0.115443	val-rmse:0.173266
# [1370]	train-rmse:0.115411	val-rmse:0.173266
# [1371]	train-rmse:0.115374	val-rmse:0.173269
# [1372]	train-rmse:0.115343	val-rmse:0.173269
# [1373]	train-rmse:0.115326	val-rmse:0.173268
# [1374]	train-rmse:0.115299	val-rmse:0.173263
# [1375]	train-rmse:0.115274	val-rmse:0.17326
# [1376]	train-rmse:0.115237	val-rmse:0.173253
# [1377]	train-rmse:0.115211	val-rmse:0.173254
# [1378]	train-rmse:0.115183	val-rmse:0.173254
# [1379]	train-rmse:0.115155	val-rmse:0.173251
# [1380]	train-rmse:0.115129	val-rmse:0.173252
# [1381]	train-rmse:0.115105	val-rmse:0.173251
# [1382]	train-rmse:0.11507	val-rmse:0.173241
# [1383]	train-rmse:0.115047	val-rmse:0.173244
# [1384]	train-rmse:0.115019	val-rmse:0.173236
# [1385]	train-rmse:0.114994	val-rmse:0.173236
# [1386]	train-rmse:0.114954	val-rmse:0.173239
# [1387]	train-rmse:0.114921	val-rmse:0.173242
# [1388]	train-rmse:0.114882	val-rmse:0.173237
# [1389]	train-rmse:0.114837	val-rmse:0.17324
# [1390]	train-rmse:0.114812	val-rmse:0.173238
# [1391]	train-rmse:0.114775	val-rmse:0.173231
# [1392]	train-rmse:0.114744	val-rmse:0.173233
# [1393]	train-rmse:0.114722	val-rmse:0.173234
# [1394]	train-rmse:0.114695	val-rmse:0.173231
# [1395]	train-rmse:0.114663	val-rmse:0.17323
# [1396]	train-rmse:0.114619	val-rmse:0.173223
# [1397]	train-rmse:0.114576	val-rmse:0.173226
# [1398]	train-rmse:0.114547	val-rmse:0.173226
# [1399]	train-rmse:0.11452	val-rmse:0.173219
# [1400]	train-rmse:0.114487	val-rmse:0.173223
# [1401]	train-rmse:0.114454	val-rmse:0.173221
# [1402]	train-rmse:0.114432	val-rmse:0.173218
# [1403]	train-rmse:0.114397	val-rmse:0.17322
# [1404]	train-rmse:0.114363	val-rmse:0.173221
# [1405]	train-rmse:0.114333	val-rmse:0.173223
# [1406]	train-rmse:0.114311	val-rmse:0.173224
# [1407]	train-rmse:0.114282	val-rmse:0.173228
# [1408]	train-rmse:0.11425	val-rmse:0.173223
# [1409]	train-rmse:0.114212	val-rmse:0.173216
# [1410]	train-rmse:0.114184	val-rmse:0.173211
# [1411]	train-rmse:0.114157	val-rmse:0.173213
# [1412]	train-rmse:0.114127	val-rmse:0.173218
# [1413]	train-rmse:0.114098	val-rmse:0.173214
# [1414]	train-rmse:0.114057	val-rmse:0.173214
# [1415]	train-rmse:0.114026	val-rmse:0.173206
# [1416]	train-rmse:0.113999	val-rmse:0.173213
# [1417]	train-rmse:0.113973	val-rmse:0.173206
# [1418]	train-rmse:0.113939	val-rmse:0.173207
# [1419]	train-rmse:0.113921	val-rmse:0.173204
# [1420]	train-rmse:0.11389	val-rmse:0.173201
# [1421]	train-rmse:0.11386	val-rmse:0.173203
# [1422]	train-rmse:0.113837	val-rmse:0.173206
# [1423]	train-rmse:0.1138	val-rmse:0.173208
# [1424]	train-rmse:0.11377	val-rmse:0.173206
# [1425]	train-rmse:0.113754	val-rmse:0.173203
# [1426]	train-rmse:0.113734	val-rmse:0.173202
# [1427]	train-rmse:0.113697	val-rmse:0.173197
# [1428]	train-rmse:0.113673	val-rmse:0.173191
# [1429]	train-rmse:0.113653	val-rmse:0.173186
# [1430]	train-rmse:0.113619	val-rmse:0.173183
# [1431]	train-rmse:0.113596	val-rmse:0.173179
# [1432]	train-rmse:0.113578	val-rmse:0.173182
# [1433]	train-rmse:0.113551	val-rmse:0.173179
# [1434]	train-rmse:0.113525	val-rmse:0.173171
# [1435]	train-rmse:0.113493	val-rmse:0.173171
# [1436]	train-rmse:0.113465	val-rmse:0.173165
# [1437]	train-rmse:0.113436	val-rmse:0.173166
# [1438]	train-rmse:0.113412	val-rmse:0.173162
# [1439]	train-rmse:0.113391	val-rmse:0.173163
# [1440]	train-rmse:0.113359	val-rmse:0.173163
# [1441]	train-rmse:0.113336	val-rmse:0.173162
# [1442]	train-rmse:0.113302	val-rmse:0.173154
# [1443]	train-rmse:0.113272	val-rmse:0.173152
# [1444]	train-rmse:0.113253	val-rmse:0.173149
# [1445]	train-rmse:0.113216	val-rmse:0.173149
# [1446]	train-rmse:0.113179	val-rmse:0.17315
# [1447]	train-rmse:0.113141	val-rmse:0.173154
# [1448]	train-rmse:0.113114	val-rmse:0.173156
# [1449]	train-rmse:0.113081	val-rmse:0.17316
# [1450]	train-rmse:0.113051	val-rmse:0.173158
# [1451]	train-rmse:0.113023	val-rmse:0.173156
# [1452]	train-rmse:0.112992	val-rmse:0.173157
# [1453]	train-rmse:0.112969	val-rmse:0.173149
# [1454]	train-rmse:0.112943	val-rmse:0.17315
# [1455]	train-rmse:0.112904	val-rmse:0.17315
# [1456]	train-rmse:0.112871	val-rmse:0.173157
# [1457]	train-rmse:0.112835	val-rmse:0.173154
# [1458]	train-rmse:0.112796	val-rmse:0.173153
# [1459]	train-rmse:0.112778	val-rmse:0.173154
# [1460]	train-rmse:0.112739	val-rmse:0.173148
# [1461]	train-rmse:0.112711	val-rmse:0.173152
# [1462]	train-rmse:0.11268	val-rmse:0.173153
# [1463]	train-rmse:0.112651	val-rmse:0.173151
# [1464]	train-rmse:0.112619	val-rmse:0.173153
# [1465]	train-rmse:0.112583	val-rmse:0.173149
# [1466]	train-rmse:0.112557	val-rmse:0.173145
# [1467]	train-rmse:0.112517	val-rmse:0.17315
# [1468]	train-rmse:0.112488	val-rmse:0.173157
# [1469]	train-rmse:0.112462	val-rmse:0.173159
# [1470]	train-rmse:0.112431	val-rmse:0.173159
# [1471]	train-rmse:0.112396	val-rmse:0.173161
# [1472]	train-rmse:0.112361	val-rmse:0.173155
# [1473]	train-rmse:0.112326	val-rmse:0.173157
# [1474]	train-rmse:0.112302	val-rmse:0.17316
# [1475]	train-rmse:0.112269	val-rmse:0.173152
# [1476]	train-rmse:0.112234	val-rmse:0.17315
# [1477]	train-rmse:0.112201	val-rmse:0.173149
# [1478]	train-rmse:0.112166	val-rmse:0.173146
# [1479]	train-rmse:0.112143	val-rmse:0.173149
# [1480]	train-rmse:0.112101	val-rmse:0.173152
# [1481]	train-rmse:0.112062	val-rmse:0.173152
# [1482]	train-rmse:0.112035	val-rmse:0.173152
# [1483]	train-rmse:0.111997	val-rmse:0.173156
# [1484]	train-rmse:0.11197	val-rmse:0.173159
# [1485]	train-rmse:0.11194	val-rmse:0.173164
# [1486]	train-rmse:0.11192	val-rmse:0.173169
# [1487]	train-rmse:0.111888	val-rmse:0.173175
# [1488]	train-rmse:0.111867	val-rmse:0.173173
# [1489]	train-rmse:0.111842	val-rmse:0.17317
# [1490]	train-rmse:0.111816	val-rmse:0.173167
# [1491]	train-rmse:0.111778	val-rmse:0.173169
# [1492]	train-rmse:0.111761	val-rmse:0.173172
# [1493]	train-rmse:0.111734	val-rmse:0.173166
# [1494]	train-rmse:0.111719	val-rmse:0.173171
# [1495]	train-rmse:0.111692	val-rmse:0.173173
# [1496]	train-rmse:0.111655	val-rmse:0.173172
# [1497]	train-rmse:0.111623	val-rmse:0.173166
# [1498]	train-rmse:0.111589	val-rmse:0.173171
# [1499]	train-rmse:0.11156	val-rmse:0.173174
# [1500]	train-rmse:0.111539	val-rmse:0.173171
# [1501]	train-rmse:0.111516	val-rmse:0.17317
# [1502]	train-rmse:0.111485	val-rmse:0.173175
# [1503]	train-rmse:0.111449	val-rmse:0.173174
# [1504]	train-rmse:0.111408	val-rmse:0.173172
# [1505]	train-rmse:0.111384	val-rmse:0.173172
# [1506]	train-rmse:0.111365	val-rmse:0.17317
# [1507]	train-rmse:0.11133	val-rmse:0.173178
# [1508]	train-rmse:0.111305	val-rmse:0.173181
# [1509]	train-rmse:0.111289	val-rmse:0.173182
# [1510]	train-rmse:0.111257	val-rmse:0.173191
# [1511]	train-rmse:0.11123	val-rmse:0.173189
# [1512]	train-rmse:0.111204	val-rmse:0.173192
# [1513]	train-rmse:0.111174	val-rmse:0.173189
# [1514]	train-rmse:0.111143	val-rmse:0.173186
# [1515]	train-rmse:0.111118	val-rmse:0.173182
# [1516]	train-rmse:0.111105	val-rmse:0.173188
# [1517]	train-rmse:0.111073	val-rmse:0.173184
# [1518]	train-rmse:0.111042	val-rmse:0.173178
# [1519]	train-rmse:0.111009	val-rmse:0.17318
# [1520]	train-rmse:0.110978	val-rmse:0.173182
# [1521]	train-rmse:0.110951	val-rmse:0.173188
# [1522]	train-rmse:0.110921	val-rmse:0.173183
# [1523]	train-rmse:0.110886	val-rmse:0.173189
# [1524]	train-rmse:0.110859	val-rmse:0.17319
# [1525]	train-rmse:0.11084	val-rmse:0.173191
# [1526]	train-rmse:0.110814	val-rmse:0.173193
# [1527]	train-rmse:0.110781	val-rmse:0.173196
# [1528]	train-rmse:0.110747	val-rmse:0.173192
# [1529]	train-rmse:0.110721	val-rmse:0.173192
# [1530]	train-rmse:0.110694	val-rmse:0.173197
# [1531]	train-rmse:0.110669	val-rmse:0.173197
# [1532]	train-rmse:0.11063	val-rmse:0.173191
# [1533]	train-rmse:0.110602	val-rmse:0.173198
# [1534]	train-rmse:0.110572	val-rmse:0.173198
# [1535]	train-rmse:0.110546	val-rmse:0.173198
# [1536]	train-rmse:0.110516	val-rmse:0.173195
# [1537]	train-rmse:0.110501	val-rmse:0.173195
# [1538]	train-rmse:0.110468	val-rmse:0.173199
# [1539]	train-rmse:0.11044	val-rmse:0.173205
# [1540]	train-rmse:0.110415	val-rmse:0.173206
# [1541]	train-rmse:0.110376	val-rmse:0.173207
# [1542]	train-rmse:0.110339	val-rmse:0.173203
# [1543]	train-rmse:0.110307	val-rmse:0.173204
# [1544]	train-rmse:0.110281	val-rmse:0.173198
# [1545]	train-rmse:0.110245	val-rmse:0.173203
# [1546]	train-rmse:0.110214	val-rmse:0.173206
# [1547]	train-rmse:0.11019	val-rmse:0.173204
# [1548]	train-rmse:0.110154	val-rmse:0.173205
# [1549]	train-rmse:0.110132	val-rmse:0.173208
# [1550]	train-rmse:0.110099	val-rmse:0.173213
# [1551]	train-rmse:0.110069	val-rmse:0.173207
# [1552]	train-rmse:0.110049	val-rmse:0.173205
# [1553]	train-rmse:0.11002	val-rmse:0.173211
# [1554]	train-rmse:0.109995	val-rmse:0.173211
# [1555]	train-rmse:0.10996	val-rmse:0.173212
# [1556]	train-rmse:0.109926	val-rmse:0.173215
# [1557]	train-rmse:0.10989	val-rmse:0.173217
# [1558]	train-rmse:0.109861	val-rmse:0.17321
# [1559]	train-rmse:0.10982	val-rmse:0.173212
# [1560]	train-rmse:0.109782	val-rmse:0.173214
# [1561]	train-rmse:0.109765	val-rmse:0.173215
# [1562]	train-rmse:0.109744	val-rmse:0.17321
# [1563]	train-rmse:0.109714	val-rmse:0.173207
# [1564]	train-rmse:0.109684	val-rmse:0.173205
# [1565]	train-rmse:0.109661	val-rmse:0.173201
# [1566]	train-rmse:0.109622	val-rmse:0.173211
# Stopping. Best iteration:
# [1466]	train-rmse:0.112557	val-rmse:0.173145
#
# loss  0.0300019068172
#
# 综合误差 0.0283064651063
# [0.013941723977472958, 0.017913851097300617, 0.068897426477721388, 0.010777417161813714, 0.030001906817230837]
# [22, 23, 26, 26, 24]
# CPU times: user 1h 39min 59s, sys: 8.08 s, total: 1h 40min 7s
# Wall time: 13min 24s

# %%
# for submit　xgb and lgb bagging
# real_test = xgb.DMatrix(physical_data.loc[test['vid'],:].values)
# param = {}
# #param['objective'] = 'multi:softprob'
# param['eta'] = 0.1  
# param['max_depth'] = 7
# param['silent'] = 1  
# #param['num_class'] = 2
# # param['scale_pos_weight'] = 3
# param['learning_rate'] = 0.03
# param['nthread'] = 7
# #param['colsample_bytree'] = 0.8
# param['objective'] = 'reg:linear'
# param['eval_metric'] = 'mae'
# param['alpha'] = 3
# param['lambda'] = 1
# param['subsample'] = 0.8

def cal_loss_2(X,y,lgb_tree,xgb_tree,learning_rate,real_test):
    param_lgb = {
    'num_leaves':128, 
    #'num_leaves':100, 
    'objective':'regression',
    'metric':'l2',
    'learning_rate': learning_rate,
    'num_threads':8,
     'subsample':0.8,
    'lambda_l1':1,
    'lambda_l2':1
    #'min_sum_hessian_in_leaf':100
    }
    param_xgb = {
        #param['objective'] = 'multi:softprob'
    'eta' : 0.1,  
    'max_depth' : 7,
    'silent' : 1,  
    'learning_rate' : learning_rate,
    'nthread' : 8,
    'objective' : 'reg:linear',
    'eval_metric' : 'rmse',
    'alpha' : 3,
    'lambda' : 1,
    'subsample': 0.8
    
    }
    num_round = n
    X_train = X
    y_train = y
    # lightgbm
    train_data = lgb.Dataset(X_train,label = y_train)
    bst = lgb.train(param_lgb, train_data, num_boost_round=lgb_tree)
    y_lgb = np.array(bst.predict(real_test))

    # xgboost
    xg_train = xgb.DMatrix(X_train, label = y_train) 
    num_round = xgb_tree
    bst = xgb.train(param_xgb, xg_train, num_round)
    y_xgb = np.array(bst.predict(xgb.DMatrix(real_test)))
    y_ = (y_lgb+y_xgb)/2
    return y_
def pinche(y,y_):
    loss = 0
    for (a,b) in zip(y,y_):
        loss += np.square(a-b)
    loss = loss/len(y)
    return loss

# %%
# submit
lgb_tree = [1200,1000,1700,2600,2000]
xgb_tree = [2200,2500,3400,5000,4200]
alpha = [0.01,0.01,0.01,0.01,0.01]
submit_df = pd.DataFrame()
for i in tqdm(range(5)):
#     X = physical_data.loc[data_set[i][0],:].values
#     y = np.array(data_set[i][1])
    # 计算相关性
    X = physical_data.loc[data_set[i][0],:]
    y = pd.Series(data_set[i][1],index=X.index)
    relation = []
    drop_name = []
    for item in X.columns:
        dest_column = X.loc[:,item]
        valid_index = dest_column[dest_column.isnull().values==False].index
        p = np.corrcoef(dest_column[valid_index],y[valid_index])[0,1]
        if str(p)=='nan':
            drop_name.append(item)
            continue
        relation.append(p)
        if abs(p)<0.001:
            drop_name.append(item)
    new_name = []
    for name in X.columns:
        if name not in drop_name:
            new_name.append(name)
    X = X.loc[:,new_name].values
    test_array = physical_data.loc[test['vid'],new_name].values
    result = cal_loss_2(X,y,lgb_tree[i],xgb_tree[i],alpha[i],test_array)
    submit_df[colume_name[i]] = result
print(submit_df)

# 计算结果反变换
for i in range(5):
    submit_df[colume_name[i]] = submit_df[colume_name[i]].apply(lambda x:np.exp(x)-1)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3159: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3093: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3093: RuntimeWarning: invalid value encountered in multiply
#   c *= 1. / np.float64(fact)
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3167: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/zhu/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3168: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
#            收缩压       舒张压    血清甘油三酯  血清高密度脂蛋白  血清低密度脂蛋白
# 0     4.894293  4.416623  0.903307  0.907488  1.361741
# 1     4.819389  4.259623  0.741996  0.948498  1.402226
# 2     4.853039  4.432735  1.400970  0.820149  1.328993
# 3     4.854724  4.363793  0.990574  0.970505  1.140764
# 4     4.954130  4.363240  1.148541  0.938735  1.528076
# 5     4.880487  4.360287  0.900654  0.977576  1.400404
# 6     4.848738  4.329467  0.706969  0.959966  1.083818
# 7     4.925280  4.480758  1.297094  0.799793  1.227767
# 8     4.862428  4.414697  1.128017  0.925891  1.180996
# 9     4.832503  4.390817  0.920273  0.817536  1.353452
# 10    4.980227  4.490771  1.077023  0.883018  1.408843
# 11    4.864045  4.415248  2.171673  0.927813  1.375255
# 12    4.863795  4.344909  0.786722  0.921636  1.431399
# 13    4.931163  4.359260  0.885274  0.789415  1.408057
# 14    4.797137  4.283696  0.703125  0.931822  1.344567
# 15    4.882504  4.336369  1.005827  0.847260  1.347418
# 16    4.805615  4.282910  0.720628  0.833993  1.002671
# 17    4.831033  4.375463  1.225790  0.945143  1.646620
# 18    4.804653  4.312727  0.706352  0.967041  1.175306
# 19    4.810980  4.334280  0.886179  0.778735  1.384748
# 20    4.664001  4.185270  0.566530  0.979529  1.184609
# 21    4.848370  4.375483  0.686376  0.857769  1.152526
# 22    4.781471  4.307748  0.734315  0.795318  1.135916
# 23    4.805582  4.267023  0.781566  0.956474  1.148543
# 24    4.846030  4.387156  0.984597  0.888981  1.388605
# 25    4.823600  4.362134  0.953991  0.801727  1.421334
# 26    5.014549  4.517755  0.955651  0.875918  1.469196
# 27    4.976383  4.465551  0.804316  0.797709  1.305465
# 28    4.696952  4.167670  0.504881  0.949810  1.096823
# 29    4.773968  4.272910  0.744608  1.049232  1.281247
# ...        ...       ...       ...       ...       ...
# 9502  4.827175  4.350609  0.790423  0.870469  1.380882
# 9503  4.725245  4.226970  0.863184  1.002870  1.302783
# 9504  4.948602  4.454967  0.567687  1.035460  1.212654
# 9505  4.829882  4.244605  0.771497  0.860181  1.149279
# 9506  4.755264  4.238690  0.537687  0.857203  1.193577
# 9507  4.899243  4.459254  1.497727  0.798301  1.518521
# 9508  4.818260  4.316433  0.836110  0.876335  1.397431
# 9509  4.730721  4.318465  0.561574  0.955383  1.054362
# 9510  4.827601  4.362981  0.918879  0.857044  1.309605
# 9511  4.773418  4.256015  0.610302  0.956680  1.174315
# 9512  4.744463  4.288209  0.677797  0.771382  1.294747
# 9513  4.875893  4.403091  1.082005  0.823779  1.406760
# 9514  4.719740  4.219100  0.696671  0.847022  1.544393
# 9515  4.719993  4.228594  0.674811  0.961226  1.132512
# 9516  5.023998  4.451096  0.817164  0.796302  1.297002
# 9517  4.883951  4.384498  0.787094  0.899155  1.243066
# 9518  5.059101  4.553663  1.290409  0.668110  1.471896
# 9519  4.879321  4.349504  1.647596  0.822657  1.469714
# 9520  4.750808  4.257235  0.535535  1.138850  1.319251
# 9521  4.762119  4.205752  0.647571  0.919989  1.161772
# 9522  4.863212  4.424156  1.207426  0.793782  1.276413
# 9523  4.796602  4.325388  0.848001  0.889260  1.471566
# 9524  4.789494  4.232121  0.756396  0.871238  1.193535
# 9525  4.773775  4.263374  0.683443  0.951034  1.306111
# 9526  4.753373  4.282391  0.525119  1.028127  0.942271
# 9527  4.941105  4.404816  0.928651  0.767980  1.337890
# 9528  4.817149  4.396253  0.790921  0.851094  1.431893
# 9529  4.878215  4.425135  1.017798  0.783130  1.426316
# 9530  4.826703  4.400243  1.049380  0.860934  1.288226
# 9531  4.929761  4.487535  1.169128  0.987465  1.520927
#
# [9532 rows x 5 columns]

# %% [markdown]
# # 8保存结果

# %%
import datetime
nowTime=datetime.datetime.now().strftime('_%Y%m%d_%H%M%S')
submit_name = '../submit/submit'+nowTime+'.csv'
submit_df.index = test['vid']
submit_df.to_csv(submit_name,header=None)
